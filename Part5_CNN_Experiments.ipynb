# %% [markdown]
# $$
# \newcommand{\mat}[1]{\boldsymbol {#1}}
# \newcommand{\mattr}[1]{\boldsymbol {#1}^\top}
# \newcommand{\matinv}[1]{\boldsymbol {#1}^{-1}}
# \newcommand{\vec}[1]{\boldsymbol {#1}}
# \newcommand{\vectr}[1]{\boldsymbol {#1}^\top}
# \newcommand{\rvar}[1]{\mathrm {#1}}
# \newcommand{\rvec}[1]{\boldsymbol{\mathrm{#1}}}
# \newcommand{\diag}{\mathop{\mathrm {diag}}}
# \newcommand{\set}[1]{\mathbb {#1}}
# \newcommand{\norm}[1]{\left\lVert#1\right\rVert}
# \newcommand{\pderiv}[2]{\frac{\partial #1}{\partial #2}}
# \newcommand{\bb}[1]{\boldsymbol{#1}}
# $$
# # Part 5: Convolutional Architecture Experiments
# <a id=part5></a>

# %% [markdown]
# In this part we will explore convolution networks and the effects of their architecture on accuracy. We'll use our deep CNN implementation and perform various experiments on it while varying the architecture. Then we'll implement our own custom architecture to see whether we can get high classification results on a large subset of CIFAR-10.
#
# Training will be performed on GPU.

# %%
import os
import re
import sys
import glob
import numpy as np
import matplotlib.pyplot as plt
import unittest
import torch
import torchvision
import torchvision.transforms as tvtf

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
seed = 42
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
plt.rcParams.update({'font.size': 12})
test = unittest.TestCase()

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir('/content/drive/MyDrive/HW2/deephw2')
# !pwd
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/HW2/deephw2

# %% [markdown]
# ## Experimenting with model architectures
# <a id=part5_3></a>

# %% [markdown]
# We will now perform a series of experiments that train various model configurations on a part of the CIFAR-10 dataset.
#
# To perform the experiments, you'll need to use a machine with a GPU since training time might be too long otherwise.

# %% [markdown]
# ### Note about running on GPUs

# %% [markdown]
# Here's an example of running a forward pass on the GPU
# (assuming you're running this notebook on a GPU-enabled machine).

# %%
from hw2.cnn import ResNet

net = ResNet(
    in_size=(3,100,100), out_classes=10, channels=[32, 64]*3,
    pool_every=4, hidden_dims=[100]*2,
    pooling_type='avg', pooling_params=dict(kernel_size=2),
)
net = net.to(device)

test_image = torch.randint(low=0, high=256, size=(3, 100, 100), dtype=torch.float).unsqueeze(0)
test_image = test_image.to(device)

test_out = net(test_image)

# %% [markdown]
# Notice how we called `.to(device)` on **both** the model and the input tensor.
# Here the `device` is a `torch.device` object that we created above. If an nvidia GPU is available on the machine you're running this on, the `device` will be `'cuda'`. When you run `.to(device)` on a model, it recursively goes over all the model parameter tensors and copies their memory to the GPU. Similarly, calling `.to(device)` on the input image also copies it.
#
# In order to train on a GPU, you need to make sure to move **all** your tensors to it. You'll get errors if you try to mix CPU and GPU tensors in a computation.

# %%
print(f'This notebook is running with device={device}')
print(f'The model parameter tensors are also on device={next(net.parameters()).device}')
print(f'The test image is also on device={test_image.device}')
print(f'The output is therefore also on device={test_out.device}')
# Out:
# This notebook is running with device=cuda
# The model parameter tensors are also on device=cuda:0
# The test image is also on device=cuda:0
# The output is therefore also on device=cuda:0

# %% [markdown]
# ### Notes on using course servers
#
# First, please read the [course servers guide](https://vistalab-technion.github.io/cs236781/assignments/hpc-servers) carefully.
#
# To run the experiments on the course servers, you can use the `py-sbatch.sh` script directly to perform a single experiment run in batch mode (since it runs python once), or use the `srun` command to do a single run in interactive mode. For example, running a single run of experiment 1 interactively (after `conda activate` of course):
#
# ```shell
# srun -c 2 --gres=gpu:1 --pty python -m hw2.experiments run-exp -n test -K 32 64 -L 2 -P 2 -H 100
# ```
#
# To perform multiple runs in batch mode with `sbatch` (e.g. for running all the configurations of an experiments), you can create your own script based on `py-sbatch.sh` and invoke whatever commands you need within it.
#
# Don't request more than **2 CPU** cores and **1 GPU** device for your runs. The code won't be able to utilize more than that anyway, so you'll see no performance gain if you do. It will only cause delays for other students using the servers.

# %% [markdown]
# ### General notes for running experiments
#
# - You can run the experiments on a different machine (e.g. the course servers) and copy the results (files)
#   to the `results` folder on your local machine.
#   This notebook will only display the results, not run the actual experiment code (except for a demo run).
# - It's important to give each experiment run a name as specified by the notebook instructions later on.
#   Each run has a `run_name` parameter that will also be the base name of the results file which this
#   notebook will expect to load.
# - You will implement the code to run the experiments in the `hw2/experiments.py` module.
#   This module has a CLI parser so that you can invoke it as a script and pass in all the
#   configuration parameters for a single experiment run.
# - You should use `python -m hw2.experiments run-exp` to run an experiment, and **not**
#   `python hw2/experiments.py run-exp`, regardless of how/where you run it.

# %% [markdown]
# ### Experiment 1: Network depth and number of filters

# %% [markdown]
# In this part we will test some different architecture configurations based on our `CNN` and `ResNet`.
# Specifically, we want to try different depths and number of features to see the effects these parameters have on the model's performance.
#
# To do this, we'll define two extra hyperparameters for our model, `K` (`filters_per_layer`) and `L` (`layers_per_block`).
# - `K` is a list, containing the number of filters we want to have in our conv layers.
# - `L` is the number of consecutive layers with the same number of filters to use.
#
# For example, if `K=[32, 64]` and `L=2` it means we want two conv layers with 32 filters followed by two conv layers with 64 filters. If we also use `pool_every=3`, the feature-extraction part of our model will be:
#
#     Conv(X,32)->ReLu->Conv(32,32)->ReLU->Conv(32,64)->ReLU->MaxPool->Conv(64,64)->ReLU
#
# We'll try various values of the `K` and `L` parameters in combination and see how each architecture trains. **All other hyperparameters are up to you**, including the choice of the optimization algorithm, the learning rate, regularization and architecture hyperparams such as `pool_every` and `hidden_dims`. Note that you should select the `pool_every` parameter wisely per experiment so that you don't end up with zero-width feature maps.
#
# You can try some short manual runs to determine some good values for the hyperparameters or implement cross-validation to do it. However, the **dataset size** you test on should be large. If you limit the number of batches, make sure to use at least 30000 training images and 5000 validation images.
#
# The important thing is that you state what you used, how you decided on it, and explain your results based on that.

# %% [markdown]
# First we need to write some code to run the experiment.
#
# **TODO**:
# 1. Implement the `cnn_experiment()` function in the `hw2/experiments.py` module.
# 1. If you haven't done so already, it would be an excellent idea to implement the **early stopping** feature of the `Trainer` class.
#
# The following block tests that your implementation works. It's also meant to show you that each experiment run creates a result file containing the parameters to reproduce and the `FitResult` object for plotting.

# %%
from hw2.experiments import load_experiment, cnn_experiment
from cs236781.plot import plot_fit

# Test experiment1 implementation on a few data samples and with a small model
cnn_experiment(
    'test_run', seed=seed, bs_train=50, batches=10, epochs=10, early_stopping=5,
    filters_per_layer=[32,64], layers_per_block=1, pool_every=1, hidden_dims=[100],
    model_type='resnet',
)

# There should now be a file 'test_run.json' in your `results/` folder.
# We can use it to load the results of the experiment.
cfg, fit_res = load_experiment('results/test_run_L1_K32-64.json')
_, _ = plot_fit(fit_res, train_test_overlay=True)

# And `cfg` contains the exact parameters to reproduce it
print('experiment config: ', cfg)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to /root/.pytorch-datasets/cifar-10-python.tar.gz
# 100%|██████████| 170M/170M [00:13<00:00, 13.1MB/s]
# Extracting /root/.pytorch-datasets/cifar-10-python.tar.gz to /root/.pytorch-datasets
# Files already downloaded and verified
# --- EPOCH 1/10 ---
# train_batch:   0%|          | 0/10 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/10 [00:00<?, ?it/s]
# --- EPOCH 2/10 ---
# train_batch:   0%|          | 0/10 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/10 [00:00<?, ?it/s]
# --- EPOCH 3/10 ---
# train_batch:   0%|          | 0/10 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/10 [00:00<?, ?it/s]
# --- EPOCH 4/10 ---
# train_batch:   0%|          | 0/10 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/10 [00:00<?, ?it/s]
# --- EPOCH 5/10 ---
# train_batch:   0%|          | 0/10 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/10 [00:00<?, ?it/s]
# --- EPOCH 6/10 ---
# train_batch:   0%|          | 0/10 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/10 [00:00<?, ?it/s]
# --- EPOCH 7/10 ---
# train_batch:   0%|          | 0/10 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/10 [00:00<?, ?it/s]
# --- EPOCH 8/10 ---
# train_batch:   0%|          | 0/10 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/10 [00:00<?, ?it/s]
# --- EPOCH 9/10 ---
# train_batch:   0%|          | 0/10 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/10 [00:00<?, ?it/s]
# --- EPOCH 10/10 ---
# train_batch:   0%|          | 0/10 [00:00<?, ?it/s]
# test_batch:   0%|          | 0/10 [00:00<?, ?it/s]
# *** Output file ./results/test_run_L1_K32-64.json written
# experiment config:  {'run_name': 'test_run', 'out_dir': './results', 'seed': 42, 'device': None, 'bs_train': 50, 'bs_test': 12, 'batches': 10, 'epochs': 10, 'early_stopping': 5, 'checkpoints': None, 'lr': 0.001, 'reg': 0.001, 'filters_per_layer': [32, 64], 'pool_every': 1, 'hidden_dims': [100], 'model_type': 'resnet', 'activation_type': 'lrelu', 'activation_params': {'negative_slope': 0.5}, 'conv_params': {'kernel_size': 3, 'stride': 1, 'padding': 1}, 'pooling_type': 'max', 'pooling_params': {'kernel_size': 2, 'stride': 2}, 'batchnorm': True, 'dropout': 0.2, 'kw': {}, 'layers_per_block': 1}

# %% [markdown]
# We'll use the following function to load multiple experiment results and plot them together.

# %%
def plot_exp_results(filename_pattern, results_dir='results'):
    fig = None
    result_files = glob.glob(os.path.join(results_dir, filename_pattern))
    result_files.sort()
    if len(result_files) == 0:
        print(f'No results found for pattern {filename_pattern}.', file=sys.stderr)
        return
    for filepath in result_files:
        m = re.match('exp\d_(\d_)?(.*)\.json', os.path.basename(filepath))
        cfg, fit_res = load_experiment(filepath)
        fig, axes = plot_fit(fit_res, fig, legend=m[2],log_loss=True)
    del cfg['filters_per_layer']
    del cfg['layers_per_block']
    print('common config: ', cfg)

# %% [markdown]
# #### Experiment 1.1: Varying the network depth (`L`)

# %% [markdown]
# First, we'll test the effect of the network depth on training.
#
# **Configuratons**:
# - `K=32` fixed, with `L=2,4,8,16` varying per run
# - `K=64` fixed, with `L=2,4,8,16` varying per run
#
# So 8 different runs in total.
#
# **Naming runs**:
# Each run should be named `exp1_1_L{}_K{}` where the braces are placeholders for the values. For example, the first run should be named `exp1_1_L2_K32`.

# %% [markdown]
# **TODO**: Run the experiment on the above configuration with the `CNN` model. Make sure the result file names are as expected. Use the following blocks to display the results.

# %%
from hw2.experiments import load_experiment, cnn_experiment

filters_per_layer_list = [32, 64]
layers_per_block_list = [2, 4, 8, 16]


hidden_dims = 1024

for K in filters_per_layer_list:
    for L in layers_per_block_list:
        lr = 1e-4
        run_name = f"exp1_1_L{L}_K{K}"
        command = (
            f"python -m hw2.experiments run-exp "
            f"--run-name {run_name} "
            f"--seed {seed} "
            f"--lr {lr} "
            f"--filters-per-layer {K} "
            f"--layers-per-block {L} "
            f"--pool-every {L} "
            f"--hidden-dims {hidden_dims} "
            f"--model-type cnn "
        )
        print(f"Running: {command}")
        # os.system(command)
        # !{command}
# Out:
# Running: python -m hw2.experiments run-exp --run-name exp1_1_L2_K32 --seed 42 --lr 0.0001 --filters-per-layer 32 --layers-per-block 2 --pool-every 2 --hidden-dims 1024 --model-type cnn
# *** Starting cnn_experiment with config:
# Namespace(run_name='exp1_1_L2_K32', out_dir='./results', seed=42, device=None, bs_train=128, bs_test=None, batches=100, epochs=100, early_stopping=3, checkpoints=None, lr=0.0001, reg=0.001, filters_per_layer=[32], layers_per_block=2, pool_every=2, hidden_dims=[1024], model_type='cnn')
# Files already downloaded and verified
# Files already downloaded and verified
# --- EPOCH 1/100 ---
# train_batch (Avg. Loss 1.988, Accuracy 28.6): 100% 100/100 [00:02<00:00, 40.40it/s]
# test_batch (Avg. Loss 1.792, Accuracy 38.2): 100% 100/100 [00:00<00:00, 188.04it/s]
# --- EPOCH 2/100 ---
# train_batch (Avg. Loss 1.717, Accuracy 39.8): 100% 100/100 [00:02<00:00, 48.03it/s]
# test_batch (Avg. Loss 1.655, Accuracy 41.6): 100% 100/100 [00:00<00:00, 191.02it/s]
# --- EPOCH 3/100 ---
# train_batch (Avg. Loss 1.612, Accuracy 43.4): 100% 100/100 [00:02<00:00, 48.13it/s]
# test_batch (Avg. Loss 1.572, Accuracy 44.5): 100% 100/100 [00:00<00:00, 192.37it/s]
# --- EPOCH 4/100 ---
# train_batch (Avg. Loss 1.543, Accuracy 45.6): 100% 100/100 [00:02<00:00, 47.28it/s]
# test_batch (Avg. Loss 1.504, Accuracy 46.6): 100% 100/100 [00:00<00:00, 190.11it/s]
# --- EPOCH 5/100 ---
# train_batch (Avg. Loss 1.482, Accuracy 48.3): 100% 100/100 [00:02<00:00, 47.85it/s]
# test_batch (Avg. Loss 1.469, Accuracy 47.7): 100% 100/100 [00:00<00:00, 191.20it/s]
# --- EPOCH 6/100 ---
# train_batch (Avg. Loss 1.469, Accuracy 48.5): 100% 100/100 [00:02<00:00, 47.60it/s]
# test_batch (Avg. Loss 1.443, Accuracy 48.9): 100% 100/100 [00:00<00:00, 191.81it/s]
# --- EPOCH 7/100 ---
# train_batch (Avg. Loss 1.417, Accuracy 50.4): 100% 100/100 [00:02<00:00, 47.86it/s]
# test_batch (Avg. Loss 1.386, Accuracy 51.3): 100% 100/100 [00:00<00:00, 193.11it/s]
# --- EPOCH 8/100 ---
# train_batch (Avg. Loss 1.386, Accuracy 51.8): 100% 100/100 [00:02<00:00, 47.59it/s]
# test_batch (Avg. Loss 1.367, Accuracy 51.2): 100% 100/100 [00:00<00:00, 188.83it/s]
# --- EPOCH 9/100 ---
# train_batch (Avg. Loss 1.347, Accuracy 52.7): 100% 100/100 [00:02<00:00, 47.50it/s]
# test_batch (Avg. Loss 1.347, Accuracy 52.8): 100% 100/100 [00:00<00:00, 191.28it/s]
# --- EPOCH 10/100 ---
# train_batch (Avg. Loss 1.314, Accuracy 53.8): 100% 100/100 [00:02<00:00, 47.90it/s]
# test_batch (Avg. Loss 1.296, Accuracy 54.4): 100% 100/100 [00:00<00:00, 189.49it/s]
# --- EPOCH 11/100 ---
# train_batch (Avg. Loss 1.271, Accuracy 55.3): 100% 100/100 [00:02<00:00, 47.28it/s]
# test_batch (Avg. Loss 1.299, Accuracy 53.4): 100% 100/100 [00:00<00:00, 189.22it/s]
# --- EPOCH 12/100 ---
# train_batch (Avg. Loss 1.259, Accuracy 55.6): 100% 100/100 [00:02<00:00, 47.47it/s]
# test_batch (Avg. Loss 1.271, Accuracy 55.1): 100% 100/100 [00:00<00:00, 189.83it/s]
# --- EPOCH 13/100 ---
# train_batch (Avg. Loss 1.234, Accuracy 56.7): 100% 100/100 [00:02<00:00, 47.16it/s]
# test_batch (Avg. Loss 1.264, Accuracy 55.4): 100% 100/100 [00:00<00:00, 189.35it/s]
# --- EPOCH 14/100 ---
# train_batch (Avg. Loss 1.221, Accuracy 57.1): 100% 100/100 [00:02<00:00, 47.00it/s]
# test_batch (Avg. Loss 1.238, Accuracy 56.5): 100% 100/100 [00:00<00:00, 186.88it/s]
# --- EPOCH 15/100 ---
# train_batch (Avg. Loss 1.209, Accuracy 58.0): 100% 100/100 [00:02<00:00, 46.76it/s]
# test_batch (Avg. Loss 1.226, Accuracy 57.5): 100% 100/100 [00:00<00:00, 191.58it/s]
# --- EPOCH 16/100 ---
# train_batch (Avg. Loss 1.186, Accuracy 58.6): 100% 100/100 [00:02<00:00, 48.00it/s]
# test_batch (Avg. Loss 1.201, Accuracy 57.9): 100% 100/100 [00:00<00:00, 191.55it/s]
# --- EPOCH 17/100 ---
# train_batch (Avg. Loss 1.158, Accuracy 59.6): 100% 100/100 [00:02<00:00, 47.40it/s]
# test_batch (Avg. Loss 1.190, Accuracy 57.1): 100% 100/100 [00:00<00:00, 191.99it/s]
# --- EPOCH 18/100 ---
# train_batch (Avg. Loss 1.163, Accuracy 59.4): 100% 100/100 [00:02<00:00, 47.09it/s]
# test_batch (Avg. Loss 1.196, Accuracy 57.9): 100% 100/100 [00:00<00:00, 191.75it/s]
# --- EPOCH 19/100 ---
# train_batch (Avg. Loss 1.139, Accuracy 60.3): 100% 100/100 [00:02<00:00, 47.21it/s]
# test_batch (Avg. Loss 1.194, Accuracy 57.2): 100% 100/100 [00:00<00:00, 188.19it/s]
# *** Output file ./results/exp1_1_L2_K32_L2_K32.json written
# Running: python -m hw2.experiments run-exp --run-name exp1_1_L4_K32 --seed 42 --lr 0.0001 --filters-per-layer 32 --layers-per-block 4 --pool-every 4 --hidden-dims 1024 --model-type cnn
# *** Starting cnn_experiment with config:
# Namespace(run_name='exp1_1_L4_K32', out_dir='./results', seed=42, device=None, bs_train=128, bs_test=None, batches=100, epochs=100, early_stopping=3, checkpoints=None, lr=0.0001, reg=0.001, filters_per_layer=[32], layers_per_block=4, pool_every=4, hidden_dims=[1024], model_type='cnn')
# Files already downloaded and verified
# Files already downloaded and verified
# --- EPOCH 1/100 ---
# train_batch (Avg. Loss 2.065, Accuracy 24.8): 100% 100/100 [00:02<00:00, 35.50it/s]
# test_batch (Avg. Loss 1.861, Accuracy 34.6): 100% 100/100 [00:00<00:00, 178.29it/s]
# --- EPOCH 2/100 ---
# train_batch (Avg. Loss 1.796, Accuracy 36.1): 100% 100/100 [00:02<00:00, 41.32it/s]
# test_batch (Avg. Loss 1.691, Accuracy 42.2): 100% 100/100 [00:00<00:00, 182.66it/s]
# --- EPOCH 3/100 ---
# train_batch (Avg. Loss 1.657, Accuracy 41.5): 100% 100/100 [00:02<00:00, 41.78it/s]
# test_batch (Avg. Loss 1.591, Accuracy 43.6): 100% 100/100 [00:00<00:00, 183.60it/s]
# --- EPOCH 4/100 ---
# train_batch (Avg. Loss 1.565, Accuracy 44.9): 100% 100/100 [00:02<00:00, 42.05it/s]
# test_batch (Avg. Loss 1.517, Accuracy 45.9): 100% 100/100 [00:00<00:00, 180.74it/s]
# --- EPOCH 5/100 ---
# train_batch (Avg. Loss 1.515, Accuracy 46.3): 100% 100/100 [00:02<00:00, 41.61it/s]
# test_batch (Avg. Loss 1.464, Accuracy 47.8): 100% 100/100 [00:00<00:00, 182.26it/s]
# --- EPOCH 6/100 ---
# train_batch (Avg. Loss 1.466, Accuracy 47.7): 100% 100/100 [00:02<00:00, 41.17it/s]
# test_batch (Avg. Loss 1.432, Accuracy 49.2): 100% 100/100 [00:00<00:00, 175.70it/s]
# --- EPOCH 7/100 ---
# train_batch (Avg. Loss 1.438, Accuracy 49.0): 100% 100/100 [00:02<00:00, 41.57it/s]
# test_batch (Avg. Loss 1.411, Accuracy 50.5): 100% 100/100 [00:00<00:00, 181.35it/s]
# --- EPOCH 8/100 ---
# train_batch (Avg. Loss 1.406, Accuracy 50.7): 100% 100/100 [00:02<00:00, 41.82it/s]
# test_batch (Avg. Loss 1.402, Accuracy 50.2): 100% 100/100 [00:00<00:00, 182.49it/s]
# --- EPOCH 9/100 ---
# train_batch (Avg. Loss 1.381, Accuracy 50.9): 100% 100/100 [00:02<00:00, 41.04it/s]
# test_batch (Avg. Loss 1.368, Accuracy 51.1): 100% 100/100 [00:00<00:00, 180.15it/s]
# --- EPOCH 10/100 ---
# train_batch (Avg. Loss 1.342, Accuracy 52.5): 100% 100/100 [00:02<00:00, 41.45it/s]
# test_batch (Avg. Loss 1.346, Accuracy 52.1): 100% 100/100 [00:00<00:00, 181.90it/s]
# --- EPOCH 11/100 ---
# train_batch (Avg. Loss 1.324, Accuracy 53.1): 100% 100/100 [00:02<00:00, 41.51it/s]
# test_batch (Avg. Loss 1.313, Accuracy 53.7): 100% 100/100 [00:00<00:00, 184.32it/s]
# --- EPOCH 12/100 ---
# train_batch (Avg. Loss 1.279, Accuracy 54.9): 100% 100/100 [00:02<00:00, 41.81it/s]
# test_batch (Avg. Loss 1.320, Accuracy 53.3): 100% 100/100 [00:00<00:00, 185.01it/s]
# --- EPOCH 13/100 ---
# train_batch (Avg. Loss 1.271, Accuracy 55.2): 100% 100/100 [00:02<00:00, 41.70it/s]
# test_batch (Avg. Loss 1.286, Accuracy 54.1): 100% 100/100 [00:00<00:00, 180.11it/s]
# --- EPOCH 14/100 ---
# train_batch (Avg. Loss 1.255, Accuracy 55.9): 100% 100/100 [00:02<00:00, 41.68it/s]
# test_batch (Avg. Loss 1.282, Accuracy 54.6): 100% 100/100 [00:00<00:00, 182.61it/s]
# --- EPOCH 15/100 ---
# train_batch (Avg. Loss 1.227, Accuracy 56.6): 100% 100/100 [00:02<00:00, 41.71it/s]
# test_batch (Avg. Loss 1.269, Accuracy 54.9): 100% 100/100 [00:00<00:00, 184.05it/s]
# --- EPOCH 16/100 ---
# train_batch (Avg. Loss 1.202, Accuracy 57.7): 100% 100/100 [00:02<00:00, 42.35it/s]
# test_batch (Avg. Loss 1.246, Accuracy 55.8): 100% 100/100 [00:00<00:00, 185.85it/s]
# --- EPOCH 17/100 ---
# train_batch (Avg. Loss 1.177, Accuracy 58.6): 100% 100/100 [00:02<00:00, 42.10it/s]
# test_batch (Avg. Loss 1.220, Accuracy 56.7): 100% 100/100 [00:00<00:00, 186.44it/s]
# --- EPOCH 18/100 ---
# train_batch (Avg. Loss 1.157, Accuracy 59.1): 100% 100/100 [00:02<00:00, 41.66it/s]
# test_batch (Avg. Loss 1.220, Accuracy 56.6): 100% 100/100 [00:00<00:00, 177.08it/s]
# --- EPOCH 19/100 ---
# train_batch (Avg. Loss 1.150, Accuracy 59.3): 100% 100/100 [00:02<00:00, 41.35it/s]
# test_batch (Avg. Loss 1.207, Accuracy 57.2): 100% 100/100 [00:00<00:00, 183.98it/s]
# --- EPOCH 20/100 ---
# train_batch (Avg. Loss 1.132, Accuracy 59.9): 100% 100/100 [00:02<00:00, 41.70it/s]
# test_batch (Avg. Loss 1.185, Accuracy 57.2): 100% 100/100 [00:00<00:00, 183.02it/s]
# --- EPOCH 21/100 ---
# train_batch (Avg. Loss 1.116, Accuracy 60.8): 100% 100/100 [00:02<00:00, 41.82it/s]
# test_batch (Avg. Loss 1.173, Accuracy 58.1): 100% 100/100 [00:00<00:00, 182.87it/s]
# --- EPOCH 22/100 ---
# train_batch (Avg. Loss 1.097, Accuracy 61.3): 100% 100/100 [00:02<00:00, 41.17it/s]
# test_batch (Avg. Loss 1.190, Accuracy 57.6): 100% 100/100 [00:00<00:00, 179.13it/s]
# --- EPOCH 23/100 ---
# train_batch (Avg. Loss 1.090, Accuracy 61.7): 100% 100/100 [00:02<00:00, 41.83it/s]
# test_batch (Avg. Loss 1.190, Accuracy 57.1): 100% 100/100 [00:00<00:00, 181.01it/s]
# --- EPOCH 24/100 ---
# train_batch (Avg. Loss 1.055, Accuracy 63.0): 100% 100/100 [00:02<00:00, 41.81it/s]
# test_batch (Avg. Loss 1.129, Accuracy 59.1): 100% 100/100 [00:00<00:00, 184.42it/s]
# --- EPOCH 25/100 ---
# train_batch (Avg. Loss 1.047, Accuracy 63.0): 100% 100/100 [00:02<00:00, 42.21it/s]
# test_batch (Avg. Loss 1.123, Accuracy 60.3): 100% 100/100 [00:00<00:00, 180.46it/s]
# --- EPOCH 26/100 ---
# train_batch (Avg. Loss 1.031, Accuracy 64.0): 100% 100/100 [00:02<00:00, 42.01it/s]
# test_batch (Avg. Loss 1.158, Accuracy 60.1): 100% 100/100 [00:00<00:00, 181.74it/s]
# --- EPOCH 27/100 ---
# train_batch (Avg. Loss 1.009, Accuracy 65.0): 100% 100/100 [00:02<00:00, 41.98it/s]
# test_batch (Avg. Loss 1.120, Accuracy 60.2): 100% 100/100 [00:00<00:00, 182.89it/s]
# --- EPOCH 28/100 ---
# train_batch (Avg. Loss 0.991, Accuracy 65.1): 100% 100/100 [00:02<00:00, 42.03it/s]
# test_batch (Avg. Loss 1.143, Accuracy 59.7): 100% 100/100 [00:00<00:00, 187.05it/s]
# *** Output file ./results/exp1_1_L4_K32_L4_K32.json written
# Running: python -m hw2.experiments run-exp --run-name exp1_1_L8_K32 --seed 42 --lr 0.0001 --filters-per-layer 32 --layers-per-block 8 --pool-every 8 --hidden-dims 1024 --model-type cnn
# *** Starting cnn_experiment with config:
# Namespace(run_name='exp1_1_L8_K32', out_dir='./results', seed=42, device=None, bs_train=128, bs_test=None, batches=100, epochs=100, early_stopping=3, checkpoints=None, lr=0.0001, reg=0.001, filters_per_layer=[32], layers_per_block=8, pool_every=8, hidden_dims=[1024], model_type='cnn')
# Files already downloaded and verified
# Files already downloaded and verified
# --- EPOCH 1/100 ---
# train_batch (Avg. Loss 2.304, Accuracy 9.8): 100% 100/100 [00:03<00:00, 30.29it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.8): 100% 100/100 [00:00<00:00, 173.92it/s]
# --- EPOCH 2/100 ---
# train_batch (Avg. Loss 2.223, Accuracy 14.6): 100% 100/100 [00:02<00:00, 34.39it/s]
# test_batch (Avg. Loss 1.993, Accuracy 28.2): 100% 100/100 [00:00<00:00, 172.70it/s]
# --- EPOCH 3/100 ---
# train_batch (Avg. Loss 1.951, Accuracy 28.3): 100% 100/100 [00:02<00:00, 34.65it/s]
# test_batch (Avg. Loss 1.921, Accuracy 28.8): 100% 100/100 [00:00<00:00, 174.50it/s]
# --- EPOCH 4/100 ---
# train_batch (Avg. Loss 1.892, Accuracy 30.6): 100% 100/100 [00:02<00:00, 34.08it/s]
# test_batch (Avg. Loss 1.860, Accuracy 32.2): 100% 100/100 [00:00<00:00, 170.20it/s]
# --- EPOCH 5/100 ---
# train_batch (Avg. Loss 1.861, Accuracy 31.7): 100% 100/100 [00:02<00:00, 34.06it/s]
# test_batch (Avg. Loss 1.831, Accuracy 31.4): 100% 100/100 [00:00<00:00, 167.96it/s]
# --- EPOCH 6/100 ---
# train_batch (Avg. Loss 1.772, Accuracy 35.2): 100% 100/100 [00:02<00:00, 34.07it/s]
# test_batch (Avg. Loss 1.739, Accuracy 37.9): 100% 100/100 [00:00<00:00, 174.48it/s]
# --- EPOCH 7/100 ---
# train_batch (Avg. Loss 1.680, Accuracy 38.9): 100% 100/100 [00:02<00:00, 33.98it/s]
# test_batch (Avg. Loss 1.622, Accuracy 41.8): 100% 100/100 [00:00<00:00, 165.35it/s]
# --- EPOCH 8/100 ---
# train_batch (Avg. Loss 1.570, Accuracy 43.8): 100% 100/100 [00:02<00:00, 33.66it/s]
# test_batch (Avg. Loss 1.508, Accuracy 46.6): 100% 100/100 [00:00<00:00, 168.79it/s]
# --- EPOCH 9/100 ---
# train_batch (Avg. Loss 1.489, Accuracy 46.7): 100% 100/100 [00:02<00:00, 33.92it/s]
# test_batch (Avg. Loss 1.447, Accuracy 48.1): 100% 100/100 [00:00<00:00, 173.99it/s]
# --- EPOCH 10/100 ---
# train_batch (Avg. Loss 1.416, Accuracy 48.4): 100% 100/100 [00:02<00:00, 34.00it/s]
# test_batch (Avg. Loss 1.414, Accuracy 49.7): 100% 100/100 [00:00<00:00, 169.95it/s]
# --- EPOCH 11/100 ---
# train_batch (Avg. Loss 1.392, Accuracy 50.2): 100% 100/100 [00:02<00:00, 33.98it/s]
# test_batch (Avg. Loss 1.381, Accuracy 50.7): 100% 100/100 [00:00<00:00, 170.52it/s]
# --- EPOCH 12/100 ---
# train_batch (Avg. Loss 1.352, Accuracy 51.8): 100% 100/100 [00:02<00:00, 34.18it/s]
# test_batch (Avg. Loss 1.359, Accuracy 52.2): 100% 100/100 [00:00<00:00, 171.38it/s]
# --- EPOCH 13/100 ---
# train_batch (Avg. Loss 1.320, Accuracy 52.4): 100% 100/100 [00:02<00:00, 34.28it/s]
# test_batch (Avg. Loss 1.312, Accuracy 52.9): 100% 100/100 [00:00<00:00, 174.56it/s]
# --- EPOCH 14/100 ---
# train_batch (Avg. Loss 1.283, Accuracy 53.9): 100% 100/100 [00:02<00:00, 34.09it/s]
# test_batch (Avg. Loss 1.313, Accuracy 53.0): 100% 100/100 [00:00<00:00, 170.46it/s]
# --- EPOCH 15/100 ---
# train_batch (Avg. Loss 1.279, Accuracy 54.9): 100% 100/100 [00:02<00:00, 33.87it/s]
# test_batch (Avg. Loss 1.265, Accuracy 54.7): 100% 100/100 [00:00<00:00, 169.96it/s]
# --- EPOCH 16/100 ---
# train_batch (Avg. Loss 1.235, Accuracy 56.5): 100% 100/100 [00:02<00:00, 34.02it/s]
# test_batch (Avg. Loss 1.258, Accuracy 55.3): 100% 100/100 [00:00<00:00, 173.83it/s]
# --- EPOCH 17/100 ---
# train_batch (Avg. Loss 1.210, Accuracy 57.4): 100% 100/100 [00:02<00:00, 34.23it/s]
# test_batch (Avg. Loss 1.237, Accuracy 55.8): 100% 100/100 [00:00<00:00, 172.60it/s]
# --- EPOCH 18/100 ---
# train_batch (Avg. Loss 1.162, Accuracy 59.0): 100% 100/100 [00:02<00:00, 34.34it/s]
# test_batch (Avg. Loss 1.206, Accuracy 57.2): 100% 100/100 [00:00<00:00, 168.35it/s]
# --- EPOCH 19/100 ---
# train_batch (Avg. Loss 1.161, Accuracy 59.1): 100% 100/100 [00:02<00:00, 34.50it/s]
# test_batch (Avg. Loss 1.217, Accuracy 57.0): 100% 100/100 [00:00<00:00, 173.73it/s]
# --- EPOCH 20/100 ---
# train_batch (Avg. Loss 1.136, Accuracy 59.7): 100% 100/100 [00:02<00:00, 34.36it/s]
# test_batch (Avg. Loss 1.203, Accuracy 56.5): 100% 100/100 [00:00<00:00, 170.47it/s]
# --- EPOCH 21/100 ---
# train_batch (Avg. Loss 1.076, Accuracy 62.2): 100% 100/100 [00:02<00:00, 34.67it/s]
# test_batch (Avg. Loss 1.195, Accuracy 57.7): 100% 100/100 [00:00<00:00, 172.42it/s]
# --- EPOCH 22/100 ---
# train_batch (Avg. Loss 1.066, Accuracy 62.4): 100% 100/100 [00:02<00:00, 34.13it/s]
# test_batch (Avg. Loss 1.164, Accuracy 58.6): 100% 100/100 [00:00<00:00, 171.56it/s]
# --- EPOCH 23/100 ---
# train_batch (Avg. Loss 1.038, Accuracy 63.2): 100% 100/100 [00:02<00:00, 34.27it/s]
# test_batch (Avg. Loss 1.145, Accuracy 59.4): 100% 100/100 [00:00<00:00, 174.51it/s]
# --- EPOCH 24/100 ---
# train_batch (Avg. Loss 0.999, Accuracy 65.0): 100% 100/100 [00:02<00:00, 34.73it/s]
# test_batch (Avg. Loss 1.154, Accuracy 59.1): 100% 100/100 [00:00<00:00, 174.57it/s]
# --- EPOCH 25/100 ---
# train_batch (Avg. Loss 0.999, Accuracy 65.2): 100% 100/100 [00:02<00:00, 34.45it/s]
# test_batch (Avg. Loss 1.131, Accuracy 59.7): 100% 100/100 [00:00<00:00, 173.93it/s]
# --- EPOCH 26/100 ---
# train_batch (Avg. Loss 0.964, Accuracy 66.8): 100% 100/100 [00:02<00:00, 34.38it/s]
# test_batch (Avg. Loss 1.124, Accuracy 60.3): 100% 100/100 [00:00<00:00, 174.48it/s]
# --- EPOCH 27/100 ---
# train_batch (Avg. Loss 0.935, Accuracy 67.1): 100% 100/100 [00:02<00:00, 34.50it/s]
# test_batch (Avg. Loss 1.143, Accuracy 60.2): 100% 100/100 [00:00<00:00, 174.97it/s]
# --- EPOCH 28/100 ---
# train_batch (Avg. Loss 0.918, Accuracy 67.7): 100% 100/100 [00:02<00:00, 34.67it/s]
# test_batch (Avg. Loss 1.145, Accuracy 60.3): 100% 100/100 [00:00<00:00, 176.35it/s]
# --- EPOCH 29/100 ---
# train_batch (Avg. Loss 0.899, Accuracy 68.9): 100% 100/100 [00:02<00:00, 33.70it/s]
# test_batch (Avg. Loss 1.094, Accuracy 62.7): 100% 100/100 [00:00<00:00, 173.25it/s]
# --- EPOCH 30/100 ---
# train_batch (Avg. Loss 0.874, Accuracy 69.7): 100% 100/100 [00:02<00:00, 34.26it/s]
# test_batch (Avg. Loss 1.098, Accuracy 61.9): 100% 100/100 [00:00<00:00, 172.91it/s]
# --- EPOCH 31/100 ---
# train_batch (Avg. Loss 0.859, Accuracy 70.3): 100% 100/100 [00:02<00:00, 34.65it/s]
# test_batch (Avg. Loss 1.157, Accuracy 60.3): 100% 100/100 [00:00<00:00, 169.08it/s]
# --- EPOCH 32/100 ---
# train_batch (Avg. Loss 0.825, Accuracy 71.2): 100% 100/100 [00:02<00:00, 34.39it/s]
# test_batch (Avg. Loss 1.113, Accuracy 62.4): 100% 100/100 [00:00<00:00, 170.25it/s]
# *** Output file ./results/exp1_1_L8_K32_L8_K32.json written
# Running: python -m hw2.experiments run-exp --run-name exp1_1_L16_K32 --seed 42 --lr 0.0001 --filters-per-layer 32 --layers-per-block 16 --pool-every 16 --hidden-dims 1024 --model-type cnn
# *** Starting cnn_experiment with config:
# Namespace(run_name='exp1_1_L16_K32', out_dir='./results', seed=42, device=None, bs_train=128, bs_test=None, batches=100, epochs=100, early_stopping=3, checkpoints=None, lr=0.0001, reg=0.001, filters_per_layer=[32], layers_per_block=16, pool_every=16, hidden_dims=[1024], model_type='cnn')
# Files already downloaded and verified
# Files already downloaded and verified
# --- EPOCH 1/100 ---
# train_batch (Avg. Loss 2.304, Accuracy 10.1): 100% 100/100 [00:04<00:00, 24.60it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100% 100/100 [00:00<00:00, 154.73it/s]
# --- EPOCH 2/100 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.6): 100% 100/100 [00:03<00:00, 26.92it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.2): 100% 100/100 [00:00<00:00, 154.53it/s]
# --- EPOCH 3/100 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.6): 100% 100/100 [00:03<00:00, 27.07it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.8): 100% 100/100 [00:00<00:00, 151.61it/s]
# --- EPOCH 4/100 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100% 100/100 [00:03<00:00, 27.14it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.5): 100% 100/100 [00:00<00:00, 150.79it/s]
# --- EPOCH 5/100 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.4): 100% 100/100 [00:03<00:00, 26.92it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.8): 100% 100/100 [00:00<00:00, 155.16it/s]
# --- EPOCH 6/100 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100% 100/100 [00:03<00:00, 27.18it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.8): 100% 100/100 [00:00<00:00, 155.14it/s]
# --- EPOCH 7/100 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.1): 100% 100/100 [00:03<00:00, 27.03it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.2): 100% 100/100 [00:00<00:00, 153.40it/s]
# *** Output file ./results/exp1_1_L16_K32_L16_K32.json written
# Running: python -m hw2.experiments run-exp --run-name exp1_1_L2_K64 --seed 42 --lr 0.0001 --filters-per-layer 64 --layers-per-block 2 --pool-every 2 --hidden-dims 1024 --model-type cnn
# *** Starting cnn_experiment with config:
# Namespace(run_name='exp1_1_L2_K64', out_dir='./results', seed=42, device=None, bs_train=128, bs_test=None, batches=100, epochs=100, early_stopping=3, checkpoints=None, lr=0.0001, reg=0.001, filters_per_layer=[64], layers_per_block=2, pool_every=2, hidden_dims=[1024], model_type='cnn')
# Files already downloaded and verified
# Files already downloaded and verified
# --- EPOCH 1/100 ---
# train_batch (Avg. Loss 1.879, Accuracy 33.5): 100% 100/100 [00:02<00:00, 39.52it/s]
# test_batch (Avg. Loss 1.674, Accuracy 41.5): 100% 100/100 [00:00<00:00, 190.38it/s]
# --- EPOCH 2/100 ---
# train_batch (Avg. Loss 1.591, Accuracy 44.2): 100% 100/100 [00:02<00:00, 46.53it/s]
# test_batch (Avg. Loss 1.534, Accuracy 46.0): 100% 100/100 [00:00<00:00, 190.02it/s]
# --- EPOCH 3/100 ---
# train_batch (Avg. Loss 1.476, Accuracy 48.2): 100% 100/100 [00:02<00:00, 46.47it/s]
# test_batch (Avg. Loss 1.444, Accuracy 49.1): 100% 100/100 [00:00<00:00, 186.84it/s]
# --- EPOCH 4/100 ---
# train_batch (Avg. Loss 1.404, Accuracy 50.4): 100% 100/100 [00:02<00:00, 46.95it/s]
# test_batch (Avg. Loss 1.406, Accuracy 49.0): 100% 100/100 [00:00<00:00, 192.45it/s]
# --- EPOCH 5/100 ---
# train_batch (Avg. Loss 1.329, Accuracy 53.1): 100% 100/100 [00:02<00:00, 46.82it/s]
# test_batch (Avg. Loss 1.317, Accuracy 53.4): 100% 100/100 [00:00<00:00, 192.18it/s]
# --- EPOCH 6/100 ---
# train_batch (Avg. Loss 1.286, Accuracy 55.0): 100% 100/100 [00:02<00:00, 46.75it/s]
# test_batch (Avg. Loss 1.289, Accuracy 53.8): 100% 100/100 [00:00<00:00, 192.39it/s]
# --- EPOCH 7/100 ---
# train_batch (Avg. Loss 1.246, Accuracy 56.2): 100% 100/100 [00:02<00:00, 46.03it/s]
# test_batch (Avg. Loss 1.229, Accuracy 56.7): 100% 100/100 [00:00<00:00, 186.12it/s]
# --- EPOCH 8/100 ---
# train_batch (Avg. Loss 1.197, Accuracy 58.4): 100% 100/100 [00:02<00:00, 46.40it/s]
# test_batch (Avg. Loss 1.226, Accuracy 56.4): 100% 100/100 [00:00<00:00, 192.51it/s]
# --- EPOCH 9/100 ---
# train_batch (Avg. Loss 1.165, Accuracy 59.0): 100% 100/100 [00:02<00:00, 46.10it/s]
# test_batch (Avg. Loss 1.189, Accuracy 58.2): 100% 100/100 [00:00<00:00, 191.53it/s]
# --- EPOCH 10/100 ---
# train_batch (Avg. Loss 1.148, Accuracy 60.0): 100% 100/100 [00:02<00:00, 46.32it/s]
# test_batch (Avg. Loss 1.175, Accuracy 57.5): 100% 100/100 [00:00<00:00, 189.41it/s]
# --- EPOCH 11/100 ---
# train_batch (Avg. Loss 1.120, Accuracy 60.9): 100% 100/100 [00:02<00:00, 46.24it/s]
# test_batch (Avg. Loss 1.151, Accuracy 59.2): 100% 100/100 [00:00<00:00, 186.70it/s]
# --- EPOCH 12/100 ---
# train_batch (Avg. Loss 1.111, Accuracy 61.5): 100% 100/100 [00:02<00:00, 46.34it/s]
# test_batch (Avg. Loss 1.129, Accuracy 60.0): 100% 100/100 [00:00<00:00, 192.69it/s]
# --- EPOCH 13/100 ---
# train_batch (Avg. Loss 1.080, Accuracy 62.8): 100% 100/100 [00:02<00:00, 47.05it/s]
# test_batch (Avg. Loss 1.149, Accuracy 59.4): 100% 100/100 [00:00<00:00, 193.03it/s]
# --- EPOCH 14/100 ---
# train_batch (Avg. Loss 1.068, Accuracy 63.0): 100% 100/100 [00:02<00:00, 46.78it/s]
# test_batch (Avg. Loss 1.104, Accuracy 61.0): 100% 100/100 [00:00<00:00, 192.29it/s]
# --- EPOCH 15/100 ---
# train_batch (Avg. Loss 1.038, Accuracy 64.1): 100% 100/100 [00:02<00:00, 46.22it/s]
# test_batch (Avg. Loss 1.067, Accuracy 61.7): 100% 100/100 [00:00<00:00, 190.20it/s]
# --- EPOCH 16/100 ---
# train_batch (Avg. Loss 1.022, Accuracy 64.4): 100% 100/100 [00:02<00:00, 46.92it/s]
# test_batch (Avg. Loss 1.100, Accuracy 60.9): 100% 100/100 [00:00<00:00, 193.22it/s]
# --- EPOCH 17/100 ---
# train_batch (Avg. Loss 1.002, Accuracy 65.6): 100% 100/100 [00:02<00:00, 46.57it/s]
# test_batch (Avg. Loss 1.054, Accuracy 62.7): 100% 100/100 [00:00<00:00, 192.79it/s]
# --- EPOCH 18/100 ---
# train_batch (Avg. Loss 1.001, Accuracy 65.5): 100% 100/100 [00:02<00:00, 47.32it/s]
# test_batch (Avg. Loss 1.054, Accuracy 62.9): 100% 100/100 [00:00<00:00, 189.30it/s]
# --- EPOCH 19/100 ---
# train_batch (Avg. Loss 0.962, Accuracy 66.8): 100% 100/100 [00:02<00:00, 46.38it/s]
# test_batch (Avg. Loss 1.061, Accuracy 63.2): 100% 100/100 [00:00<00:00, 188.72it/s]
# --- EPOCH 20/100 ---
# train_batch (Avg. Loss 0.968, Accuracy 66.0): 100% 100/100 [00:02<00:00, 46.83it/s]
# test_batch (Avg. Loss 1.052, Accuracy 62.7): 100% 100/100 [00:00<00:00, 192.43it/s]
# --- EPOCH 21/100 ---
# train_batch (Avg. Loss 0.939, Accuracy 67.8): 100% 100/100 [00:02<00:00, 46.25it/s]
# test_batch (Avg. Loss 1.019, Accuracy 63.9): 100% 100/100 [00:00<00:00, 190.65it/s]
# --- EPOCH 22/100 ---
# train_batch (Avg. Loss 0.940, Accuracy 67.3): 100% 100/100 [00:02<00:00, 46.50it/s]
# test_batch (Avg. Loss 1.012, Accuracy 64.1): 100% 100/100 [00:00<00:00, 191.81it/s]
# --- EPOCH 23/100 ---
# train_batch (Avg. Loss 0.930, Accuracy 68.1): 100% 100/100 [00:02<00:00, 46.36it/s]
# test_batch (Avg. Loss 1.012, Accuracy 64.3): 100% 100/100 [00:00<00:00, 191.49it/s]
# --- EPOCH 24/100 ---
# train_batch (Avg. Loss 0.901, Accuracy 69.3): 100% 100/100 [00:02<00:00, 46.21it/s]
# test_batch (Avg. Loss 1.025, Accuracy 63.8): 100% 100/100 [00:00<00:00, 190.39it/s]
# --- EPOCH 25/100 ---
# train_batch (Avg. Loss 0.893, Accuracy 69.2): 100% 100/100 [00:02<00:00, 46.90it/s]
# test_batch (Avg. Loss 0.994, Accuracy 65.8): 100% 100/100 [00:00<00:00, 191.04it/s]
# --- EPOCH 26/100 ---
# train_batch (Avg. Loss 0.891, Accuracy 69.3): 100% 100/100 [00:02<00:00, 46.28it/s]
# test_batch (Avg. Loss 1.021, Accuracy 64.1): 100% 100/100 [00:00<00:00, 191.10it/s]
# --- EPOCH 27/100 ---
# train_batch (Avg. Loss 0.863, Accuracy 69.9): 100% 100/100 [00:02<00:00, 46.96it/s]
# test_batch (Avg. Loss 0.984, Accuracy 65.2): 100% 100/100 [00:00<00:00, 193.86it/s]
# --- EPOCH 28/100 ---
# train_batch (Avg. Loss 0.857, Accuracy 70.8): 100% 100/100 [00:02<00:00, 46.62it/s]
# test_batch (Avg. Loss 0.971, Accuracy 66.5): 100% 100/100 [00:00<00:00, 190.50it/s]
# --- EPOCH 29/100 ---
# train_batch (Avg. Loss 0.842, Accuracy 71.1): 100% 100/100 [00:02<00:00, 46.82it/s]
# test_batch (Avg. Loss 0.965, Accuracy 66.6): 100% 100/100 [00:00<00:00, 193.21it/s]
# --- EPOCH 30/100 ---
# train_batch (Avg. Loss 0.837, Accuracy 71.2): 100% 100/100 [00:02<00:00, 46.54it/s]
# test_batch (Avg. Loss 0.971, Accuracy 66.1): 100% 100/100 [00:00<00:00, 191.89it/s]
# --- EPOCH 31/100 ---
# train_batch (Avg. Loss 0.823, Accuracy 71.9): 100% 100/100 [00:02<00:00, 46.29it/s]
# test_batch (Avg. Loss 0.961, Accuracy 66.1): 100% 100/100 [00:00<00:00, 188.88it/s]
# --- EPOCH 32/100 ---
# train_batch (Avg. Loss 0.826, Accuracy 71.8): 100% 100/100 [00:02<00:00, 46.56it/s]
# test_batch (Avg. Loss 0.966, Accuracy 65.8): 100% 100/100 [00:00<00:00, 189.04it/s]
# *** Output file ./results/exp1_1_L2_K64_L2_K64.json written
# Running: python -m hw2.experiments run-exp --run-name exp1_1_L4_K64 --seed 42 --lr 0.0001 --filters-per-layer 64 --layers-per-block 4 --pool-every 4 --hidden-dims 1024 --model-type cnn
# *** Starting cnn_experiment with config:
# Namespace(run_name='exp1_1_L4_K64', out_dir='./results', seed=42, device=None, bs_train=128, bs_test=None, batches=100, epochs=100, early_stopping=3, checkpoints=None, lr=0.0001, reg=0.001, filters_per_layer=[64], layers_per_block=4, pool_every=4, hidden_dims=[1024], model_type='cnn')
# Files already downloaded and verified
# Files already downloaded and verified
# --- EPOCH 1/100 ---
# train_batch (Avg. Loss 1.963, Accuracy 29.5): 100% 100/100 [00:02<00:00, 36.70it/s]
# test_batch (Avg. Loss 1.740, Accuracy 39.8): 100% 100/100 [00:00<00:00, 181.09it/s]
# --- EPOCH 2/100 ---
# train_batch (Avg. Loss 1.657, Accuracy 41.9): 100% 100/100 [00:02<00:00, 42.24it/s]
# test_batch (Avg. Loss 1.576, Accuracy 43.8): 100% 100/100 [00:00<00:00, 184.52it/s]
# --- EPOCH 3/100 ---
# train_batch (Avg. Loss 1.519, Accuracy 46.0): 100% 100/100 [00:02<00:00, 42.03it/s]
# test_batch (Avg. Loss 1.490, Accuracy 46.8): 100% 100/100 [00:00<00:00, 183.09it/s]
# --- EPOCH 4/100 ---
# train_batch (Avg. Loss 1.444, Accuracy 49.0): 100% 100/100 [00:02<00:00, 42.36it/s]
# test_batch (Avg. Loss 1.416, Accuracy 49.5): 100% 100/100 [00:00<00:00, 180.42it/s]
# --- EPOCH 5/100 ---
# train_batch (Avg. Loss 1.396, Accuracy 50.1): 100% 100/100 [00:02<00:00, 41.97it/s]
# test_batch (Avg. Loss 1.371, Accuracy 51.1): 100% 100/100 [00:00<00:00, 182.50it/s]
# --- EPOCH 6/100 ---
# train_batch (Avg. Loss 1.368, Accuracy 50.7): 100% 100/100 [00:02<00:00, 42.24it/s]
# test_batch (Avg. Loss 1.329, Accuracy 52.4): 100% 100/100 [00:00<00:00, 182.47it/s]
# --- EPOCH 7/100 ---
# train_batch (Avg. Loss 1.313, Accuracy 53.6): 100% 100/100 [00:02<00:00, 42.02it/s]
# test_batch (Avg. Loss 1.310, Accuracy 53.8): 100% 100/100 [00:00<00:00, 184.46it/s]
# --- EPOCH 8/100 ---
# train_batch (Avg. Loss 1.279, Accuracy 53.8): 100% 100/100 [00:02<00:00, 42.32it/s]
# test_batch (Avg. Loss 1.288, Accuracy 53.5): 100% 100/100 [00:00<00:00, 187.85it/s]
# --- EPOCH 9/100 ---
# train_batch (Avg. Loss 1.238, Accuracy 55.7): 100% 100/100 [00:02<00:00, 41.89it/s]
# test_batch (Avg. Loss 1.252, Accuracy 55.3): 100% 100/100 [00:00<00:00, 184.22it/s]
# --- EPOCH 10/100 ---
# train_batch (Avg. Loss 1.210, Accuracy 56.8): 100% 100/100 [00:02<00:00, 42.09it/s]
# test_batch (Avg. Loss 1.215, Accuracy 56.7): 100% 100/100 [00:00<00:00, 181.15it/s]
# --- EPOCH 11/100 ---
# train_batch (Avg. Loss 1.158, Accuracy 58.3): 100% 100/100 [00:02<00:00, 41.08it/s]
# test_batch (Avg. Loss 1.192, Accuracy 57.3): 100% 100/100 [00:00<00:00, 182.78it/s]
# --- EPOCH 12/100 ---
# train_batch (Avg. Loss 1.123, Accuracy 60.6): 100% 100/100 [00:02<00:00, 42.44it/s]
# test_batch (Avg. Loss 1.162, Accuracy 58.2): 100% 100/100 [00:00<00:00, 187.29it/s]
# --- EPOCH 13/100 ---
# train_batch (Avg. Loss 1.082, Accuracy 62.2): 100% 100/100 [00:02<00:00, 42.04it/s]
# test_batch (Avg. Loss 1.203, Accuracy 56.8): 100% 100/100 [00:00<00:00, 183.39it/s]
# --- EPOCH 14/100 ---
# train_batch (Avg. Loss 1.059, Accuracy 62.4): 100% 100/100 [00:02<00:00, 41.84it/s]
# test_batch (Avg. Loss 1.102, Accuracy 59.7): 100% 100/100 [00:00<00:00, 187.32it/s]
# --- EPOCH 15/100 ---
# train_batch (Avg. Loss 1.019, Accuracy 64.0): 100% 100/100 [00:02<00:00, 42.28it/s]
# test_batch (Avg. Loss 1.132, Accuracy 60.2): 100% 100/100 [00:00<00:00, 185.14it/s]
# --- EPOCH 16/100 ---
# train_batch (Avg. Loss 0.993, Accuracy 65.3): 100% 100/100 [00:02<00:00, 42.24it/s]
# test_batch (Avg. Loss 1.094, Accuracy 60.6): 100% 100/100 [00:00<00:00, 188.19it/s]
# --- EPOCH 17/100 ---
# train_batch (Avg. Loss 0.961, Accuracy 66.0): 100% 100/100 [00:02<00:00, 42.20it/s]
# test_batch (Avg. Loss 1.065, Accuracy 61.8): 100% 100/100 [00:00<00:00, 178.43it/s]
# --- EPOCH 18/100 ---
# train_batch (Avg. Loss 0.932, Accuracy 67.7): 100% 100/100 [00:02<00:00, 41.53it/s]
# test_batch (Avg. Loss 1.087, Accuracy 61.5): 100% 100/100 [00:00<00:00, 188.51it/s]
# --- EPOCH 19/100 ---
# train_batch (Avg. Loss 0.915, Accuracy 67.8): 100% 100/100 [00:02<00:00, 42.57it/s]
# test_batch (Avg. Loss 1.042, Accuracy 63.5): 100% 100/100 [00:00<00:00, 186.74it/s]
# --- EPOCH 20/100 ---
# train_batch (Avg. Loss 0.872, Accuracy 69.8): 100% 100/100 [00:02<00:00, 42.15it/s]
# test_batch (Avg. Loss 1.019, Accuracy 64.2): 100% 100/100 [00:00<00:00, 186.37it/s]
# --- EPOCH 21/100 ---
# train_batch (Avg. Loss 0.864, Accuracy 70.3): 100% 100/100 [00:02<00:00, 42.24it/s]
# test_batch (Avg. Loss 1.030, Accuracy 63.8): 100% 100/100 [00:00<00:00, 188.10it/s]
# --- EPOCH 22/100 ---
# train_batch (Avg. Loss 0.851, Accuracy 70.0): 100% 100/100 [00:02<00:00, 42.22it/s]
# test_batch (Avg. Loss 1.023, Accuracy 64.6): 100% 100/100 [00:00<00:00, 181.66it/s]
# --- EPOCH 23/100 ---
# train_batch (Avg. Loss 0.808, Accuracy 71.8): 100% 100/100 [00:02<00:00, 42.32it/s]
# test_batch (Avg. Loss 0.997, Accuracy 64.9): 100% 100/100 [00:00<00:00, 182.96it/s]
# --- EPOCH 24/100 ---
# train_batch (Avg. Loss 0.788, Accuracy 72.7): 100% 100/100 [00:02<00:00, 41.97it/s]
# test_batch (Avg. Loss 1.016, Accuracy 64.0): 100% 100/100 [00:00<00:00, 183.84it/s]
# --- EPOCH 25/100 ---
# train_batch (Avg. Loss 0.765, Accuracy 73.4): 100% 100/100 [00:02<00:00, 42.08it/s]
# test_batch (Avg. Loss 0.996, Accuracy 65.1): 100% 100/100 [00:00<00:00, 186.27it/s]
# --- EPOCH 26/100 ---
# train_batch (Avg. Loss 0.742, Accuracy 74.3): 100% 100/100 [00:02<00:00, 42.30it/s]
# test_batch (Avg. Loss 0.982, Accuracy 66.2): 100% 100/100 [00:00<00:00, 181.72it/s]
# --- EPOCH 27/100 ---
# train_batch (Avg. Loss 0.724, Accuracy 75.2): 100% 100/100 [00:02<00:00, 42.58it/s]
# test_batch (Avg. Loss 1.003, Accuracy 65.2): 100% 100/100 [00:00<00:00, 185.25it/s]
# --- EPOCH 28/100 ---
# train_batch (Avg. Loss 0.703, Accuracy 75.5): 100% 100/100 [00:02<00:00, 42.29it/s]
# test_batch (Avg. Loss 0.995, Accuracy 65.2): 100% 100/100 [00:00<00:00, 185.60it/s]
# --- EPOCH 29/100 ---
# train_batch (Avg. Loss 0.673, Accuracy 77.0): 100% 100/100 [00:02<00:00, 42.16it/s]
# test_batch (Avg. Loss 0.972, Accuracy 66.3): 100% 100/100 [00:00<00:00, 187.64it/s]
# --- EPOCH 30/100 ---
# train_batch (Avg. Loss 0.640, Accuracy 78.0): 100% 100/100 [00:02<00:00, 42.57it/s]
# test_batch (Avg. Loss 0.996, Accuracy 66.0): 100% 100/100 [00:00<00:00, 185.87it/s]
# --- EPOCH 31/100 ---
# train_batch (Avg. Loss 0.622, Accuracy 78.7): 100% 100/100 [00:02<00:00, 42.21it/s]
# test_batch (Avg. Loss 0.985, Accuracy 65.8): 100% 100/100 [00:00<00:00, 185.96it/s]
# --- EPOCH 32/100 ---
# train_batch (Avg. Loss 0.602, Accuracy 79.7): 100% 100/100 [00:02<00:00, 42.07it/s]
# test_batch (Avg. Loss 1.002, Accuracy 66.5): 100% 100/100 [00:00<00:00, 184.46it/s]
# --- EPOCH 33/100 ---
# train_batch (Avg. Loss 0.585, Accuracy 80.2): 100% 100/100 [00:02<00:00, 41.92it/s]
# test_batch (Avg. Loss 0.986, Accuracy 66.8): 100% 100/100 [00:00<00:00, 187.80it/s]
# --- EPOCH 34/100 ---
# train_batch (Avg. Loss 0.580, Accuracy 80.0): 100% 100/100 [00:02<00:00, 42.49it/s]
# test_batch (Avg. Loss 1.021, Accuracy 65.9): 100% 100/100 [00:00<00:00, 185.16it/s]
# --- EPOCH 35/100 ---
# train_batch (Avg. Loss 0.552, Accuracy 81.3): 100% 100/100 [00:02<00:00, 42.12it/s]
# test_batch (Avg. Loss 1.020, Accuracy 65.1): 100% 100/100 [00:00<00:00, 185.91it/s]
# --- EPOCH 36/100 ---
# train_batch (Avg. Loss 0.532, Accuracy 82.2): 100% 100/100 [00:02<00:00, 42.23it/s]
# test_batch (Avg. Loss 1.031, Accuracy 66.7): 100% 100/100 [00:00<00:00, 183.64it/s]
# *** Output file ./results/exp1_1_L4_K64_L4_K64.json written
# Running: python -m hw2.experiments run-exp --run-name exp1_1_L8_K64 --seed 42 --lr 0.0001 --filters-per-layer 64 --layers-per-block 8 --pool-every 8 --hidden-dims 1024 --model-type cnn
# *** Starting cnn_experiment with config:
# Namespace(run_name='exp1_1_L8_K64', out_dir='./results', seed=42, device=None, bs_train=128, bs_test=None, batches=100, epochs=100, early_stopping=3, checkpoints=None, lr=0.0001, reg=0.001, filters_per_layer=[64], layers_per_block=8, pool_every=8, hidden_dims=[1024], model_type='cnn')
# Files already downloaded and verified
# Files already downloaded and verified
# --- EPOCH 1/100 ---
# train_batch (Avg. Loss 2.260, Accuracy 13.7): 100% 100/100 [00:03<00:00, 31.25it/s]
# test_batch (Avg. Loss 2.082, Accuracy 26.5): 100% 100/100 [00:00<00:00, 176.17it/s]
# --- EPOCH 2/100 ---
# train_batch (Avg. Loss 1.939, Accuracy 30.1): 100% 100/100 [00:02<00:00, 35.74it/s]
# test_batch (Avg. Loss 1.813, Accuracy 36.9): 100% 100/100 [00:00<00:00, 175.71it/s]
# --- EPOCH 3/100 ---
# train_batch (Avg. Loss 1.683, Accuracy 39.9): 100% 100/100 [00:02<00:00, 35.68it/s]
# test_batch (Avg. Loss 1.569, Accuracy 43.6): 100% 100/100 [00:00<00:00, 171.86it/s]
# --- EPOCH 4/100 ---
# train_batch (Avg. Loss 1.523, Accuracy 44.3): 100% 100/100 [00:02<00:00, 35.98it/s]
# test_batch (Avg. Loss 1.487, Accuracy 47.0): 100% 100/100 [00:00<00:00, 171.57it/s]
# --- EPOCH 5/100 ---
# train_batch (Avg. Loss 1.452, Accuracy 47.9): 100% 100/100 [00:02<00:00, 35.05it/s]
# test_batch (Avg. Loss 1.369, Accuracy 50.2): 100% 100/100 [00:00<00:00, 173.22it/s]
# --- EPOCH 6/100 ---
# train_batch (Avg. Loss 1.368, Accuracy 51.2): 100% 100/100 [00:02<00:00, 35.60it/s]
# test_batch (Avg. Loss 1.321, Accuracy 52.0): 100% 100/100 [00:00<00:00, 171.69it/s]
# --- EPOCH 7/100 ---
# train_batch (Avg. Loss 1.320, Accuracy 53.0): 100% 100/100 [00:02<00:00, 35.95it/s]
# test_batch (Avg. Loss 1.294, Accuracy 53.7): 100% 100/100 [00:00<00:00, 175.29it/s]
# --- EPOCH 8/100 ---
# train_batch (Avg. Loss 1.274, Accuracy 54.7): 100% 100/100 [00:02<00:00, 35.21it/s]
# test_batch (Avg. Loss 1.269, Accuracy 53.8): 100% 100/100 [00:00<00:00, 172.78it/s]
# --- EPOCH 9/100 ---
# train_batch (Avg. Loss 1.229, Accuracy 56.0): 100% 100/100 [00:02<00:00, 36.16it/s]
# test_batch (Avg. Loss 1.246, Accuracy 54.5): 100% 100/100 [00:00<00:00, 173.19it/s]
# --- EPOCH 10/100 ---
# train_batch (Avg. Loss 1.203, Accuracy 56.8): 100% 100/100 [00:02<00:00, 35.78it/s]
# test_batch (Avg. Loss 1.189, Accuracy 56.7): 100% 100/100 [00:00<00:00, 174.53it/s]
# --- EPOCH 11/100 ---
# train_batch (Avg. Loss 1.136, Accuracy 59.8): 100% 100/100 [00:02<00:00, 35.45it/s]
# test_batch (Avg. Loss 1.242, Accuracy 55.4): 100% 100/100 [00:00<00:00, 168.66it/s]
# --- EPOCH 12/100 ---
# train_batch (Avg. Loss 1.092, Accuracy 62.0): 100% 100/100 [00:02<00:00, 35.20it/s]
# test_batch (Avg. Loss 1.149, Accuracy 59.0): 100% 100/100 [00:00<00:00, 162.39it/s]
# --- EPOCH 13/100 ---
# train_batch (Avg. Loss 1.071, Accuracy 62.6): 100% 100/100 [00:02<00:00, 35.45it/s]
# test_batch (Avg. Loss 1.121, Accuracy 60.2): 100% 100/100 [00:00<00:00, 173.54it/s]
# --- EPOCH 14/100 ---
# train_batch (Avg. Loss 1.018, Accuracy 64.1): 100% 100/100 [00:02<00:00, 35.48it/s]
# test_batch (Avg. Loss 1.133, Accuracy 58.9): 100% 100/100 [00:00<00:00, 173.06it/s]
# --- EPOCH 15/100 ---
# train_batch (Avg. Loss 0.980, Accuracy 65.0): 100% 100/100 [00:02<00:00, 35.53it/s]
# test_batch (Avg. Loss 1.090, Accuracy 60.7): 100% 100/100 [00:00<00:00, 174.23it/s]
# --- EPOCH 16/100 ---
# train_batch (Avg. Loss 0.949, Accuracy 67.0): 100% 100/100 [00:02<00:00, 35.02it/s]
# test_batch (Avg. Loss 1.086, Accuracy 61.3): 100% 100/100 [00:00<00:00, 174.41it/s]
# --- EPOCH 17/100 ---
# train_batch (Avg. Loss 0.922, Accuracy 67.4): 100% 100/100 [00:02<00:00, 35.31it/s]
# test_batch (Avg. Loss 1.059, Accuracy 62.6): 100% 100/100 [00:00<00:00, 173.24it/s]
# --- EPOCH 18/100 ---
# train_batch (Avg. Loss 0.879, Accuracy 68.8): 100% 100/100 [00:02<00:00, 35.45it/s]
# test_batch (Avg. Loss 1.072, Accuracy 63.0): 100% 100/100 [00:00<00:00, 171.64it/s]
# --- EPOCH 19/100 ---
# train_batch (Avg. Loss 0.846, Accuracy 70.4): 100% 100/100 [00:02<00:00, 34.78it/s]
# test_batch (Avg. Loss 1.024, Accuracy 64.6): 100% 100/100 [00:00<00:00, 171.94it/s]
# --- EPOCH 20/100 ---
# train_batch (Avg. Loss 0.822, Accuracy 71.2): 100% 100/100 [00:02<00:00, 35.69it/s]
# test_batch (Avg. Loss 1.031, Accuracy 64.3): 100% 100/100 [00:00<00:00, 174.32it/s]
# --- EPOCH 21/100 ---
# train_batch (Avg. Loss 0.798, Accuracy 71.7): 100% 100/100 [00:02<00:00, 35.60it/s]
# test_batch (Avg. Loss 1.048, Accuracy 64.4): 100% 100/100 [00:00<00:00, 172.27it/s]
# --- EPOCH 22/100 ---
# train_batch (Avg. Loss 0.758, Accuracy 73.8): 100% 100/100 [00:02<00:00, 35.27it/s]
# test_batch (Avg. Loss 1.046, Accuracy 64.2): 100% 100/100 [00:00<00:00, 171.12it/s]
# *** Output file ./results/exp1_1_L8_K64_L8_K64.json written
# Running: python -m hw2.experiments run-exp --run-name exp1_1_L16_K64 --seed 42 --lr 0.0001 --filters-per-layer 64 --layers-per-block 16 --pool-every 16 --hidden-dims 1024 --model-type cnn
# *** Starting cnn_experiment with config:
# Namespace(run_name='exp1_1_L16_K64', out_dir='./results', seed=42, device=None, bs_train=128, bs_test=None, batches=100, epochs=100, early_stopping=3, checkpoints=None, lr=0.0001, reg=0.001, filters_per_layer=[64], layers_per_block=16, pool_every=16, hidden_dims=[1024], model_type='cnn')
# Files already downloaded and verified
# Files already downloaded and verified
# --- EPOCH 1/100 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.3): 100% 100/100 [00:03<00:00, 26.29it/s]
# test_batch (Avg. Loss 2.304, Accuracy 9.6): 100% 100/100 [00:00<00:00, 156.47it/s]
# --- EPOCH 2/100 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.1): 100% 100/100 [00:03<00:00, 28.94it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.8): 100% 100/100 [00:00<00:00, 158.08it/s]
# --- EPOCH 3/100 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100% 100/100 [00:03<00:00, 29.18it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.8): 100% 100/100 [00:00<00:00, 155.53it/s]
# --- EPOCH 4/100 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.1): 100% 100/100 [00:03<00:00, 29.07it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.0): 100% 100/100 [00:00<00:00, 157.60it/s]
# --- EPOCH 5/100 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.1): 100% 100/100 [00:03<00:00, 28.76it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.8): 100% 100/100 [00:00<00:00, 155.49it/s]
# --- EPOCH 6/100 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100% 100/100 [00:03<00:00, 29.02it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.8): 100% 100/100 [00:00<00:00, 155.70it/s]
# --- EPOCH 7/100 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.5): 100% 100/100 [00:03<00:00, 29.04it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100% 100/100 [00:00<00:00, 154.98it/s]
# *** Output file ./results/exp1_1_L16_K64_L16_K64.json written

# %%
plot_exp_results('exp1_1_L*_K32*.json')
# Out:
# common config:  {'run_name': 'exp1_1_L8_K32', 'out_dir': './results', 'seed': 42, 'device': None, 'bs_train': 128, 'bs_test': 32, 'batches': 100, 'epochs': 100, 'early_stopping': 3, 'checkpoints': None, 'lr': 0.0001, 'reg': 0.001, 'pool_every': 8, 'hidden_dims': [1024], 'model_type': 'cnn', 'activation_type': 'lrelu', 'activation_params': {'negative_slope': 0.25}, 'conv_params': {'kernel_size': 3, 'stride': 1, 'padding': 1}, 'pooling_type': 'max', 'pooling_params': {'kernel_size': 2, 'stride': 2}, 'batchnorm': True, 'dropout': 0.2, 'kw': {}}

# %%
plot_exp_results('exp1_1_L*_K64*.json')
# Out:
# common config:  {'run_name': 'exp1_1_L8_K64', 'out_dir': './results', 'seed': 42, 'device': None, 'bs_train': 128, 'bs_test': 32, 'batches': 100, 'epochs': 100, 'early_stopping': 3, 'checkpoints': None, 'lr': 0.0001, 'reg': 0.001, 'pool_every': 8, 'hidden_dims': [1024], 'model_type': 'cnn', 'activation_type': 'lrelu', 'activation_params': {'negative_slope': 0.25}, 'conv_params': {'kernel_size': 3, 'stride': 1, 'padding': 1}, 'pooling_type': 'max', 'pooling_params': {'kernel_size': 2, 'stride': 2}, 'batchnorm': True, 'dropout': 0.2, 'kw': {}}

# %% [markdown]
# #### Experiment 1.2: Varying the number of filters per layer (`K`)

# %% [markdown]
# Now we'll test the effect of the number of convolutional filters in each layer.
#
# **Configuratons**:
# - `L=2` fixed, with `K=[32],[64],[128]` varying per run.
# - `L=4` fixed, with `K=[32],[64],[128]` varying per run.
# - `L=8` fixed, with `K=[32],[64],[128]` varying per run.
#
# So 9 different runs in total. To clarify, each run `K` takes the value of a list with a single element.
#
# **Naming runs**:
# Each run should be named `exp1_2_L{}_K{}` where the braces are placeholders for the values. For example, the first run should be named `exp1_2_L2_K32`.

# %% [markdown]
# **TODO**: Run the experiment on the above configuration with the `CNN` model. Make sure the result file names are as expected. Use the following blocks to display the results.

# %%
from hw2.experiments import cnn_experiment

filters_per_layer_list = [32, 64, 128]
layers_per_block_list = [2, 4, 8]

hidden_dims = 1024

for L in layers_per_block_list:
    for K in filters_per_layer_list:
        lr = 1e-4
        run_name = f"exp1_2_L{L}_K{K}"
        command = (
            f"python -m hw2.experiments run-exp "
            f"--run-name {run_name} "
            f"--lr {lr} "
            f"--filters-per-layer {K} "
            f"--layers-per-block {L} "
            f"--pool-every {L} "
            f"--hidden-dims {hidden_dims} "
            f"--model-type cnn "
        )
        print(f"Running: {command}")
        # !{command}
# Out:
# Running: python -m hw2.experiments run-exp --run-name exp1_2_L2_K32 --lr 0.0001 --filters-per-layer 32 --layers-per-block 2 --pool-every 2 --hidden-dims 1024 --model-type cnn
# *** Starting cnn_experiment with config:
# Namespace(run_name='exp1_2_L2_K32', out_dir='./results', seed=None, device=None, bs_train=128, bs_test=None, batches=100, epochs=100, early_stopping=3, checkpoints=None, lr=0.0001, reg=0.001, filters_per_layer=[32], layers_per_block=2, pool_every=2, hidden_dims=[1024], model_type='cnn')
# Files already downloaded and verified
# Files already downloaded and verified
# --- EPOCH 1/100 ---
# train_batch (Avg. Loss 1.962, Accuracy 31.0): 100% 100/100 [00:02<00:00, 39.99it/s]
# test_batch (Avg. Loss 1.770, Accuracy 37.7): 100% 100/100 [00:00<00:00, 190.47it/s]
# --- EPOCH 2/100 ---
# train_batch (Avg. Loss 1.678, Accuracy 41.1): 100% 100/100 [00:02<00:00, 47.25it/s]
# test_batch (Avg. Loss 1.630, Accuracy 42.6): 100% 100/100 [00:00<00:00, 195.86it/s]
# --- EPOCH 3/100 ---
# train_batch (Avg. Loss 1.601, Accuracy 44.2): 100% 100/100 [00:02<00:00, 46.16it/s]
# test_batch (Avg. Loss 1.556, Accuracy 44.2): 100% 100/100 [00:00<00:00, 192.30it/s]
# --- EPOCH 4/100 ---
# train_batch (Avg. Loss 1.526, Accuracy 46.7): 100% 100/100 [00:02<00:00, 47.84it/s]
# test_batch (Avg. Loss 1.520, Accuracy 45.8): 100% 100/100 [00:00<00:00, 191.60it/s]
# --- EPOCH 5/100 ---
# train_batch (Avg. Loss 1.506, Accuracy 47.3): 100% 100/100 [00:02<00:00, 48.88it/s]
# test_batch (Avg. Loss 1.470, Accuracy 47.9): 100% 100/100 [00:00<00:00, 195.13it/s]
# --- EPOCH 6/100 ---
# train_batch (Avg. Loss 1.450, Accuracy 49.0): 100% 100/100 [00:02<00:00, 48.43it/s]
# test_batch (Avg. Loss 1.446, Accuracy 48.6): 100% 100/100 [00:00<00:00, 188.51it/s]
# --- EPOCH 7/100 ---
# train_batch (Avg. Loss 1.408, Accuracy 51.2): 100% 100/100 [00:02<00:00, 48.33it/s]
# test_batch (Avg. Loss 1.431, Accuracy 49.1): 100% 100/100 [00:00<00:00, 191.59it/s]
# --- EPOCH 8/100 ---
# train_batch (Avg. Loss 1.378, Accuracy 52.1): 100% 100/100 [00:02<00:00, 47.47it/s]
# test_batch (Avg. Loss 1.379, Accuracy 51.9): 100% 100/100 [00:00<00:00, 193.40it/s]
# --- EPOCH 9/100 ---
# train_batch (Avg. Loss 1.345, Accuracy 53.5): 100% 100/100 [00:02<00:00, 49.16it/s]
# test_batch (Avg. Loss 1.358, Accuracy 52.6): 100% 100/100 [00:00<00:00, 196.43it/s]
# --- EPOCH 10/100 ---
# train_batch (Avg. Loss 1.322, Accuracy 53.5): 100% 100/100 [00:02<00:00, 48.88it/s]
# test_batch (Avg. Loss 1.314, Accuracy 53.4): 100% 100/100 [00:00<00:00, 193.11it/s]
# --- EPOCH 11/100 ---
# train_batch (Avg. Loss 1.299, Accuracy 55.0): 100% 100/100 [00:02<00:00, 48.70it/s]
# test_batch (Avg. Loss 1.299, Accuracy 53.9): 100% 100/100 [00:00<00:00, 190.25it/s]
# --- EPOCH 12/100 ---
# train_batch (Avg. Loss 1.266, Accuracy 56.1): 100% 100/100 [00:02<00:00, 47.46it/s]
# test_batch (Avg. Loss 1.307, Accuracy 53.1): 100% 100/100 [00:00<00:00, 196.85it/s]
# --- EPOCH 13/100 ---
# train_batch (Avg. Loss 1.259, Accuracy 56.3): 100% 100/100 [00:02<00:00, 48.67it/s]
# test_batch (Avg. Loss 1.266, Accuracy 56.0): 100% 100/100 [00:00<00:00, 194.74it/s]
# --- EPOCH 14/100 ---
# train_batch (Avg. Loss 1.235, Accuracy 56.9): 100% 100/100 [00:02<00:00, 48.89it/s]
# test_batch (Avg. Loss 1.271, Accuracy 55.4): 100% 100/100 [00:00<00:00, 195.05it/s]
# --- EPOCH 15/100 ---
# train_batch (Avg. Loss 1.217, Accuracy 57.8): 100% 100/100 [00:02<00:00, 48.98it/s]
# test_batch (Avg. Loss 1.272, Accuracy 54.9): 100% 100/100 [00:00<00:00, 193.01it/s]
# --- EPOCH 16/100 ---
# train_batch (Avg. Loss 1.200, Accuracy 58.6): 100% 100/100 [00:02<00:00, 48.30it/s]
# test_batch (Avg. Loss 1.233, Accuracy 56.2): 100% 100/100 [00:00<00:00, 193.36it/s]
# --- EPOCH 17/100 ---
# train_batch (Avg. Loss 1.178, Accuracy 59.4): 100% 100/100 [00:02<00:00, 48.62it/s]
# test_batch (Avg. Loss 1.224, Accuracy 56.4): 100% 100/100 [00:00<00:00, 195.09it/s]
# --- EPOCH 18/100 ---
# train_batch (Avg. Loss 1.178, Accuracy 59.3): 100% 100/100 [00:02<00:00, 48.84it/s]
# test_batch (Avg. Loss 1.196, Accuracy 58.4): 100% 100/100 [00:00<00:00, 196.00it/s]
# --- EPOCH 19/100 ---
# train_batch (Avg. Loss 1.154, Accuracy 60.6): 100% 100/100 [00:02<00:00, 49.39it/s]
# test_batch (Avg. Loss 1.186, Accuracy 57.5): 100% 100/100 [00:00<00:00, 189.92it/s]
# --- EPOCH 20/100 ---
# train_batch (Avg. Loss 1.132, Accuracy 61.5): 100% 100/100 [00:02<00:00, 48.52it/s]
# test_batch (Avg. Loss 1.183, Accuracy 58.4): 100% 100/100 [00:00<00:00, 192.39it/s]
# --- EPOCH 21/100 ---
# train_batch (Avg. Loss 1.114, Accuracy 61.2): 100% 100/100 [00:02<00:00, 48.42it/s]
# test_batch (Avg. Loss 1.166, Accuracy 59.0): 100% 100/100 [00:00<00:00, 192.77it/s]
# --- EPOCH 22/100 ---
# train_batch (Avg. Loss 1.119, Accuracy 61.4): 100% 100/100 [00:02<00:00, 48.37it/s]
# test_batch (Avg. Loss 1.159, Accuracy 59.4): 100% 100/100 [00:00<00:00, 195.14it/s]
# --- EPOCH 23/100 ---
# train_batch (Avg. Loss 1.111, Accuracy 61.0): 100% 100/100 [00:02<00:00, 49.13it/s]
# test_batch (Avg. Loss 1.167, Accuracy 58.3): 100% 100/100 [00:00<00:00, 193.72it/s]
# --- EPOCH 24/100 ---
# train_batch (Avg. Loss 1.104, Accuracy 62.0): 100% 100/100 [00:02<00:00, 49.05it/s]
# test_batch (Avg. Loss 1.142, Accuracy 59.1): 100% 100/100 [00:00<00:00, 195.14it/s]
# --- EPOCH 25/100 ---
# train_batch (Avg. Loss 1.082, Accuracy 62.8): 100% 100/100 [00:02<00:00, 48.79it/s]
# test_batch (Avg. Loss 1.130, Accuracy 59.9): 100% 100/100 [00:00<00:00, 190.35it/s]
# --- EPOCH 26/100 ---
# train_batch (Avg. Loss 1.082, Accuracy 62.4): 100% 100/100 [00:02<00:00, 48.52it/s]
# test_batch (Avg. Loss 1.122, Accuracy 60.0): 100% 100/100 [00:00<00:00, 192.92it/s]
# --- EPOCH 27/100 ---
# train_batch (Avg. Loss 1.067, Accuracy 63.3): 100% 100/100 [00:02<00:00, 48.61it/s]
# test_batch (Avg. Loss 1.133, Accuracy 60.6): 100% 100/100 [00:00<00:00, 194.06it/s]
# --- EPOCH 28/100 ---
# train_batch (Avg. Loss 1.060, Accuracy 63.5): 100% 100/100 [00:02<00:00, 49.09it/s]
# test_batch (Avg. Loss 1.130, Accuracy 59.9): 100% 100/100 [00:00<00:00, 195.56it/s]
# --- EPOCH 29/100 ---
# train_batch (Avg. Loss 1.046, Accuracy 63.5): 100% 100/100 [00:02<00:00, 49.21it/s]
# test_batch (Avg. Loss 1.115, Accuracy 60.4): 100% 100/100 [00:00<00:00, 195.65it/s]
# --- EPOCH 30/100 ---
# train_batch (Avg. Loss 1.050, Accuracy 63.8): 100% 100/100 [00:02<00:00, 48.83it/s]
# test_batch (Avg. Loss 1.118, Accuracy 60.7): 100% 100/100 [00:00<00:00, 196.27it/s]
# --- EPOCH 31/100 ---
# train_batch (Avg. Loss 1.054, Accuracy 63.4): 100% 100/100 [00:02<00:00, 48.77it/s]
# test_batch (Avg. Loss 1.103, Accuracy 61.5): 100% 100/100 [00:00<00:00, 195.67it/s]
# --- EPOCH 32/100 ---
# train_batch (Avg. Loss 1.015, Accuracy 64.7): 100% 100/100 [00:02<00:00, 48.91it/s]
# test_batch (Avg. Loss 1.105, Accuracy 60.3): 100% 100/100 [00:00<00:00, 192.61it/s]
# --- EPOCH 33/100 ---
# train_batch (Avg. Loss 1.024, Accuracy 65.1): 100% 100/100 [00:02<00:00, 49.10it/s]
# test_batch (Avg. Loss 1.089, Accuracy 61.2): 100% 100/100 [00:00<00:00, 192.52it/s]
# --- EPOCH 34/100 ---
# train_batch (Avg. Loss 1.015, Accuracy 65.2): 100% 100/100 [00:02<00:00, 48.94it/s]
# test_batch (Avg. Loss 1.081, Accuracy 62.0): 100% 100/100 [00:00<00:00, 192.52it/s]
# --- EPOCH 35/100 ---
# train_batch (Avg. Loss 0.995, Accuracy 65.6): 100% 100/100 [00:02<00:00, 48.25it/s]
# test_batch (Avg. Loss 1.086, Accuracy 61.5): 100% 100/100 [00:00<00:00, 191.32it/s]
# --- EPOCH 36/100 ---
# train_batch (Avg. Loss 1.005, Accuracy 65.5): 100% 100/100 [00:02<00:00, 47.53it/s]
# test_batch (Avg. Loss 1.102, Accuracy 60.4): 100% 100/100 [00:00<00:00, 192.85it/s]
# --- EPOCH 37/100 ---
# train_batch (Avg. Loss 0.988, Accuracy 66.1): 100% 100/100 [00:02<00:00, 48.77it/s]
# test_batch (Avg. Loss 1.071, Accuracy 62.0): 100% 100/100 [00:00<00:00, 197.74it/s]
# *** Output file ./results/exp1_2_L2_K32_L2_K32.json written
# Running: python -m hw2.experiments run-exp --run-name exp1_2_L2_K64 --lr 0.0001 --filters-per-layer 64 --layers-per-block 2 --pool-every 2 --hidden-dims 1024 --model-type cnn
# *** Starting cnn_experiment with config:
# Namespace(run_name='exp1_2_L2_K64', out_dir='./results', seed=None, device=None, bs_train=128, bs_test=None, batches=100, epochs=100, early_stopping=3, checkpoints=None, lr=0.0001, reg=0.001, filters_per_layer=[64], layers_per_block=2, pool_every=2, hidden_dims=[1024], model_type='cnn')
# Files already downloaded and verified
# Files already downloaded and verified
# --- EPOCH 1/100 ---
# train_batch (Avg. Loss 1.901, Accuracy 32.4): 100% 100/100 [00:02<00:00, 39.64it/s]
# test_batch (Avg. Loss 1.671, Accuracy 42.8): 100% 100/100 [00:00<00:00, 191.57it/s]
# --- EPOCH 2/100 ---
# train_batch (Avg. Loss 1.611, Accuracy 43.8): 100% 100/100 [00:02<00:00, 46.38it/s]
# test_batch (Avg. Loss 1.526, Accuracy 46.4): 100% 100/100 [00:00<00:00, 189.48it/s]
# --- EPOCH 3/100 ---
# train_batch (Avg. Loss 1.484, Accuracy 47.8): 100% 100/100 [00:02<00:00, 46.63it/s]
# test_batch (Avg. Loss 1.446, Accuracy 49.5): 100% 100/100 [00:00<00:00, 190.02it/s]
# --- EPOCH 4/100 ---
# train_batch (Avg. Loss 1.415, Accuracy 50.5): 100% 100/100 [00:02<00:00, 45.88it/s]
# test_batch (Avg. Loss 1.423, Accuracy 48.8): 100% 100/100 [00:00<00:00, 187.78it/s]
# --- EPOCH 5/100 ---
# train_batch (Avg. Loss 1.348, Accuracy 52.4): 100% 100/100 [00:02<00:00, 45.86it/s]
# test_batch (Avg. Loss 1.352, Accuracy 51.7): 100% 100/100 [00:00<00:00, 191.29it/s]
# --- EPOCH 6/100 ---
# train_batch (Avg. Loss 1.294, Accuracy 54.8): 100% 100/100 [00:02<00:00, 46.04it/s]
# test_batch (Avg. Loss 1.316, Accuracy 53.2): 100% 100/100 [00:00<00:00, 190.64it/s]
# --- EPOCH 7/100 ---
# train_batch (Avg. Loss 1.246, Accuracy 56.4): 100% 100/100 [00:02<00:00, 46.09it/s]
# test_batch (Avg. Loss 1.260, Accuracy 55.9): 100% 100/100 [00:00<00:00, 191.95it/s]
# --- EPOCH 8/100 ---
# train_batch (Avg. Loss 1.252, Accuracy 57.0): 100% 100/100 [00:02<00:00, 46.39it/s]
# test_batch (Avg. Loss 1.227, Accuracy 56.0): 100% 100/100 [00:00<00:00, 189.13it/s]
# --- EPOCH 9/100 ---
# train_batch (Avg. Loss 1.200, Accuracy 59.0): 100% 100/100 [00:02<00:00, 45.70it/s]
# test_batch (Avg. Loss 1.200, Accuracy 57.8): 100% 100/100 [00:00<00:00, 189.85it/s]
# --- EPOCH 10/100 ---
# train_batch (Avg. Loss 1.157, Accuracy 59.9): 100% 100/100 [00:02<00:00, 46.56it/s]
# test_batch (Avg. Loss 1.212, Accuracy 57.0): 100% 100/100 [00:00<00:00, 191.27it/s]
# --- EPOCH 11/100 ---
# train_batch (Avg. Loss 1.130, Accuracy 61.3): 100% 100/100 [00:02<00:00, 46.34it/s]
# test_batch (Avg. Loss 1.194, Accuracy 57.8): 100% 100/100 [00:00<00:00, 189.56it/s]
# --- EPOCH 12/100 ---
# train_batch (Avg. Loss 1.110, Accuracy 61.3): 100% 100/100 [00:02<00:00, 46.23it/s]
# test_batch (Avg. Loss 1.167, Accuracy 58.6): 100% 100/100 [00:00<00:00, 190.96it/s]
# --- EPOCH 13/100 ---
# train_batch (Avg. Loss 1.100, Accuracy 61.8): 100% 100/100 [00:02<00:00, 46.67it/s]
# test_batch (Avg. Loss 1.158, Accuracy 59.6): 100% 100/100 [00:00<00:00, 188.27it/s]
# --- EPOCH 14/100 ---
# train_batch (Avg. Loss 1.064, Accuracy 63.5): 100% 100/100 [00:02<00:00, 46.16it/s]
# test_batch (Avg. Loss 1.132, Accuracy 59.4): 100% 100/100 [00:00<00:00, 188.02it/s]
# --- EPOCH 15/100 ---
# train_batch (Avg. Loss 1.061, Accuracy 63.6): 100% 100/100 [00:02<00:00, 46.25it/s]
# test_batch (Avg. Loss 1.113, Accuracy 60.6): 100% 100/100 [00:00<00:00, 185.66it/s]
# --- EPOCH 16/100 ---
# train_batch (Avg. Loss 1.040, Accuracy 64.4): 100% 100/100 [00:02<00:00, 45.96it/s]
# test_batch (Avg. Loss 1.088, Accuracy 61.4): 100% 100/100 [00:00<00:00, 189.27it/s]
# --- EPOCH 17/100 ---
# train_batch (Avg. Loss 1.016, Accuracy 65.0): 100% 100/100 [00:02<00:00, 46.26it/s]
# test_batch (Avg. Loss 1.073, Accuracy 61.2): 100% 100/100 [00:00<00:00, 187.09it/s]
# --- EPOCH 18/100 ---
# train_batch (Avg. Loss 1.020, Accuracy 64.5): 100% 100/100 [00:02<00:00, 46.23it/s]
# test_batch (Avg. Loss 1.075, Accuracy 61.9): 100% 100/100 [00:00<00:00, 189.53it/s]
# --- EPOCH 19/100 ---
# train_batch (Avg. Loss 0.988, Accuracy 66.2): 100% 100/100 [00:02<00:00, 44.81it/s]
# test_batch (Avg. Loss 1.062, Accuracy 62.2): 100% 100/100 [00:00<00:00, 180.72it/s]
# --- EPOCH 20/100 ---
# train_batch (Avg. Loss 0.999, Accuracy 65.9): 100% 100/100 [00:02<00:00, 46.27it/s]
# test_batch (Avg. Loss 1.061, Accuracy 62.8): 100% 100/100 [00:00<00:00, 190.58it/s]
# --- EPOCH 21/100 ---
# train_batch (Avg. Loss 0.994, Accuracy 65.8): 100% 100/100 [00:02<00:00, 46.95it/s]
# test_batch (Avg. Loss 1.086, Accuracy 61.7): 100% 100/100 [00:00<00:00, 190.87it/s]
# --- EPOCH 22/100 ---
# train_batch (Avg. Loss 0.975, Accuracy 65.8): 100% 100/100 [00:02<00:00, 46.34it/s]
# test_batch (Avg. Loss 1.068, Accuracy 62.3): 100% 100/100 [00:00<00:00, 189.14it/s]
# --- EPOCH 23/100 ---
# train_batch (Avg. Loss 0.972, Accuracy 66.6): 100% 100/100 [00:02<00:00, 45.70it/s]
# test_batch (Avg. Loss 1.039, Accuracy 62.6): 100% 100/100 [00:00<00:00, 183.71it/s]
# *** Output file ./results/exp1_2_L2_K64_L2_K64.json written
# Running: python -m hw2.experiments run-exp --run-name exp1_2_L2_K128 --lr 0.0001 --filters-per-layer 128 --layers-per-block 2 --pool-every 2 --hidden-dims 1024 --model-type cnn
# *** Starting cnn_experiment with config:
# Namespace(run_name='exp1_2_L2_K128', out_dir='./results', seed=None, device=None, bs_train=128, bs_test=None, batches=100, epochs=100, early_stopping=3, checkpoints=None, lr=0.0001, reg=0.001, filters_per_layer=[128], layers_per_block=2, pool_every=2, hidden_dims=[1024], model_type='cnn')
# Files already downloaded and verified
# Files already downloaded and verified
# --- EPOCH 1/100 ---
# train_batch (Avg. Loss 1.830, Accuracy 35.2): 100% 100/100 [00:02<00:00, 34.17it/s]
# test_batch (Avg. Loss 1.599, Accuracy 43.4): 100% 100/100 [00:00<00:00, 182.51it/s]
# --- EPOCH 2/100 ---
# train_batch (Avg. Loss 1.537, Accuracy 45.8): 100% 100/100 [00:02<00:00, 39.02it/s]
# test_batch (Avg. Loss 1.458, Accuracy 48.6): 100% 100/100 [00:00<00:00, 184.53it/s]
# --- EPOCH 3/100 ---
# train_batch (Avg. Loss 1.401, Accuracy 51.0): 100% 100/100 [00:02<00:00, 39.09it/s]
# test_batch (Avg. Loss 1.344, Accuracy 52.5): 100% 100/100 [00:00<00:00, 182.91it/s]
# --- EPOCH 4/100 ---
# train_batch (Avg. Loss 1.334, Accuracy 53.6): 100% 100/100 [00:02<00:00, 38.81it/s]
# test_batch (Avg. Loss 1.285, Accuracy 54.8): 100% 100/100 [00:00<00:00, 179.01it/s]
# --- EPOCH 5/100 ---
# train_batch (Avg. Loss 1.255, Accuracy 56.2): 100% 100/100 [00:02<00:00, 39.04it/s]
# test_batch (Avg. Loss 1.248, Accuracy 55.9): 100% 100/100 [00:00<00:00, 183.36it/s]
# --- EPOCH 6/100 ---
# train_batch (Avg. Loss 1.190, Accuracy 58.9): 100% 100/100 [00:02<00:00, 38.82it/s]
# test_batch (Avg. Loss 1.216, Accuracy 57.7): 100% 100/100 [00:00<00:00, 180.70it/s]
# --- EPOCH 7/100 ---
# train_batch (Avg. Loss 1.173, Accuracy 59.0): 100% 100/100 [00:02<00:00, 38.64it/s]
# test_batch (Avg. Loss 1.185, Accuracy 58.2): 100% 100/100 [00:00<00:00, 181.80it/s]
# --- EPOCH 8/100 ---
# train_batch (Avg. Loss 1.130, Accuracy 60.8): 100% 100/100 [00:02<00:00, 38.85it/s]
# test_batch (Avg. Loss 1.147, Accuracy 59.4): 100% 100/100 [00:00<00:00, 182.88it/s]
# --- EPOCH 9/100 ---
# train_batch (Avg. Loss 1.108, Accuracy 61.5): 100% 100/100 [00:02<00:00, 38.96it/s]
# test_batch (Avg. Loss 1.165, Accuracy 58.9): 100% 100/100 [00:00<00:00, 183.05it/s]
# --- EPOCH 10/100 ---
# train_batch (Avg. Loss 1.071, Accuracy 63.1): 100% 100/100 [00:02<00:00, 38.57it/s]
# test_batch (Avg. Loss 1.129, Accuracy 59.9): 100% 100/100 [00:00<00:00, 181.55it/s]
# --- EPOCH 11/100 ---
# train_batch (Avg. Loss 1.063, Accuracy 62.6): 100% 100/100 [00:02<00:00, 38.61it/s]
# test_batch (Avg. Loss 1.100, Accuracy 60.6): 100% 100/100 [00:00<00:00, 179.80it/s]
# --- EPOCH 12/100 ---
# train_batch (Avg. Loss 1.037, Accuracy 64.4): 100% 100/100 [00:02<00:00, 38.73it/s]
# test_batch (Avg. Loss 1.083, Accuracy 62.2): 100% 100/100 [00:00<00:00, 177.38it/s]
# --- EPOCH 13/100 ---
# train_batch (Avg. Loss 1.005, Accuracy 65.3): 100% 100/100 [00:02<00:00, 38.68it/s]
# test_batch (Avg. Loss 1.098, Accuracy 61.0): 100% 100/100 [00:00<00:00, 184.78it/s]
# --- EPOCH 14/100 ---
# train_batch (Avg. Loss 0.975, Accuracy 66.3): 100% 100/100 [00:02<00:00, 38.29it/s]
# test_batch (Avg. Loss 1.085, Accuracy 61.1): 100% 100/100 [00:00<00:00, 179.68it/s]
# --- EPOCH 15/100 ---
# train_batch (Avg. Loss 0.966, Accuracy 66.5): 100% 100/100 [00:02<00:00, 38.85it/s]
# test_batch (Avg. Loss 1.052, Accuracy 62.6): 100% 100/100 [00:00<00:00, 180.63it/s]
# --- EPOCH 16/100 ---
# train_batch (Avg. Loss 0.962, Accuracy 66.6): 100% 100/100 [00:02<00:00, 38.98it/s]
# test_batch (Avg. Loss 1.067, Accuracy 62.7): 100% 100/100 [00:00<00:00, 182.48it/s]
# --- EPOCH 17/100 ---
# train_batch (Avg. Loss 0.974, Accuracy 66.6): 100% 100/100 [00:02<00:00, 39.10it/s]
# test_batch (Avg. Loss 1.031, Accuracy 64.4): 100% 100/100 [00:00<00:00, 182.37it/s]
# --- EPOCH 18/100 ---
# train_batch (Avg. Loss 0.941, Accuracy 67.4): 100% 100/100 [00:02<00:00, 38.73it/s]
# test_batch (Avg. Loss 1.023, Accuracy 64.2): 100% 100/100 [00:00<00:00, 182.31it/s]
# --- EPOCH 19/100 ---
# train_batch (Avg. Loss 0.932, Accuracy 67.9): 100% 100/100 [00:02<00:00, 38.62it/s]
# test_batch (Avg. Loss 1.036, Accuracy 63.2): 100% 100/100 [00:00<00:00, 179.49it/s]
# --- EPOCH 20/100 ---
# train_batch (Avg. Loss 0.915, Accuracy 68.2): 100% 100/100 [00:02<00:00, 39.18it/s]
# test_batch (Avg. Loss 1.048, Accuracy 62.4): 100% 100/100 [00:00<00:00, 181.54it/s]
# *** Output file ./results/exp1_2_L2_K128_L2_K128.json written
# Running: python -m hw2.experiments run-exp --run-name exp1_2_L4_K32 --lr 0.0001 --filters-per-layer 32 --layers-per-block 4 --pool-every 4 --hidden-dims 1024 --model-type cnn
# *** Starting cnn_experiment with config:
# Namespace(run_name='exp1_2_L4_K32', out_dir='./results', seed=None, device=None, bs_train=128, bs_test=None, batches=100, epochs=100, early_stopping=3, checkpoints=None, lr=0.0001, reg=0.001, filters_per_layer=[32], layers_per_block=4, pool_every=4, hidden_dims=[1024], model_type='cnn')
# Files already downloaded and verified
# Files already downloaded and verified
# --- EPOCH 1/100 ---
# train_batch (Avg. Loss 2.055, Accuracy 25.7): 100% 100/100 [00:02<00:00, 37.42it/s]
# test_batch (Avg. Loss 1.918, Accuracy 33.3): 100% 100/100 [00:00<00:00, 186.12it/s]
# --- EPOCH 2/100 ---
# train_batch (Avg. Loss 1.844, Accuracy 35.7): 100% 100/100 [00:02<00:00, 42.91it/s]
# test_batch (Avg. Loss 1.784, Accuracy 36.8): 100% 100/100 [00:00<00:00, 185.19it/s]
# --- EPOCH 3/100 ---
# train_batch (Avg. Loss 1.702, Accuracy 40.3): 100% 100/100 [00:02<00:00, 42.60it/s]
# test_batch (Avg. Loss 1.625, Accuracy 43.9): 100% 100/100 [00:00<00:00, 185.98it/s]
# --- EPOCH 4/100 ---
# train_batch (Avg. Loss 1.606, Accuracy 42.8): 100% 100/100 [00:02<00:00, 42.47it/s]
# test_batch (Avg. Loss 1.559, Accuracy 44.7): 100% 100/100 [00:00<00:00, 186.94it/s]
# --- EPOCH 5/100 ---
# train_batch (Avg. Loss 1.550, Accuracy 45.0): 100% 100/100 [00:02<00:00, 42.39it/s]
# test_batch (Avg. Loss 1.542, Accuracy 44.7): 100% 100/100 [00:00<00:00, 186.60it/s]
# --- EPOCH 6/100 ---
# train_batch (Avg. Loss 1.505, Accuracy 46.4): 100% 100/100 [00:02<00:00, 42.23it/s]
# test_batch (Avg. Loss 1.489, Accuracy 47.9): 100% 100/100 [00:00<00:00, 185.64it/s]
# --- EPOCH 7/100 ---
# train_batch (Avg. Loss 1.471, Accuracy 48.4): 100% 100/100 [00:02<00:00, 42.97it/s]
# test_batch (Avg. Loss 1.457, Accuracy 49.0): 100% 100/100 [00:00<00:00, 187.25it/s]
# --- EPOCH 8/100 ---
# train_batch (Avg. Loss 1.436, Accuracy 49.2): 100% 100/100 [00:02<00:00, 42.53it/s]
# test_batch (Avg. Loss 1.450, Accuracy 49.5): 100% 100/100 [00:00<00:00, 182.99it/s]
# --- EPOCH 9/100 ---
# train_batch (Avg. Loss 1.406, Accuracy 50.3): 100% 100/100 [00:02<00:00, 41.79it/s]
# test_batch (Avg. Loss 1.388, Accuracy 50.2): 100% 100/100 [00:00<00:00, 186.74it/s]
# --- EPOCH 10/100 ---
# train_batch (Avg. Loss 1.360, Accuracy 51.7): 100% 100/100 [00:02<00:00, 42.85it/s]
# test_batch (Avg. Loss 1.369, Accuracy 52.2): 100% 100/100 [00:00<00:00, 186.98it/s]
# --- EPOCH 11/100 ---
# train_batch (Avg. Loss 1.347, Accuracy 51.9): 100% 100/100 [00:02<00:00, 42.75it/s]
# test_batch (Avg. Loss 1.357, Accuracy 52.0): 100% 100/100 [00:00<00:00, 190.17it/s]
# --- EPOCH 12/100 ---
# train_batch (Avg. Loss 1.316, Accuracy 53.6): 100% 100/100 [00:02<00:00, 43.17it/s]
# test_batch (Avg. Loss 1.315, Accuracy 53.5): 100% 100/100 [00:00<00:00, 181.82it/s]
# --- EPOCH 13/100 ---
# train_batch (Avg. Loss 1.288, Accuracy 55.0): 100% 100/100 [00:02<00:00, 41.63it/s]
# test_batch (Avg. Loss 1.295, Accuracy 53.9): 100% 100/100 [00:00<00:00, 184.19it/s]
# --- EPOCH 14/100 ---
# train_batch (Avg. Loss 1.276, Accuracy 54.7): 100% 100/100 [00:02<00:00, 41.82it/s]
# test_batch (Avg. Loss 1.283, Accuracy 55.0): 100% 100/100 [00:00<00:00, 185.30it/s]
# --- EPOCH 15/100 ---
# train_batch (Avg. Loss 1.247, Accuracy 55.9): 100% 100/100 [00:02<00:00, 42.14it/s]
# test_batch (Avg. Loss 1.258, Accuracy 55.4): 100% 100/100 [00:00<00:00, 186.94it/s]
# --- EPOCH 16/100 ---
# train_batch (Avg. Loss 1.234, Accuracy 56.3): 100% 100/100 [00:02<00:00, 42.09it/s]
# test_batch (Avg. Loss 1.269, Accuracy 54.7): 100% 100/100 [00:00<00:00, 185.03it/s]
# --- EPOCH 17/100 ---
# train_batch (Avg. Loss 1.194, Accuracy 57.8): 100% 100/100 [00:02<00:00, 41.68it/s]
# test_batch (Avg. Loss 1.232, Accuracy 55.9): 100% 100/100 [00:00<00:00, 182.86it/s]
# --- EPOCH 18/100 ---
# train_batch (Avg. Loss 1.200, Accuracy 58.2): 100% 100/100 [00:02<00:00, 42.12it/s]
# test_batch (Avg. Loss 1.215, Accuracy 57.4): 100% 100/100 [00:00<00:00, 181.77it/s]
# --- EPOCH 19/100 ---
# train_batch (Avg. Loss 1.170, Accuracy 58.1): 100% 100/100 [00:02<00:00, 41.91it/s]
# test_batch (Avg. Loss 1.195, Accuracy 57.3): 100% 100/100 [00:00<00:00, 184.92it/s]
# --- EPOCH 20/100 ---
# train_batch (Avg. Loss 1.146, Accuracy 60.1): 100% 100/100 [00:02<00:00, 41.76it/s]
# test_batch (Avg. Loss 1.206, Accuracy 56.9): 100% 100/100 [00:00<00:00, 187.03it/s]
# --- EPOCH 21/100 ---
# train_batch (Avg. Loss 1.146, Accuracy 59.5): 100% 100/100 [00:02<00:00, 42.05it/s]
# test_batch (Avg. Loss 1.207, Accuracy 57.0): 100% 100/100 [00:00<00:00, 185.07it/s]
# *** Output file ./results/exp1_2_L4_K32_L4_K32.json written
# Running: python -m hw2.experiments run-exp --run-name exp1_2_L4_K64 --lr 0.0001 --filters-per-layer 64 --layers-per-block 4 --pool-every 4 --hidden-dims 1024 --model-type cnn
# *** Starting cnn_experiment with config:
# Namespace(run_name='exp1_2_L4_K64', out_dir='./results', seed=None, device=None, bs_train=128, bs_test=None, batches=100, epochs=100, early_stopping=3, checkpoints=None, lr=0.0001, reg=0.001, filters_per_layer=[64], layers_per_block=4, pool_every=4, hidden_dims=[1024], model_type='cnn')
# Files already downloaded and verified
# Files already downloaded and verified
# --- EPOCH 1/100 ---
# train_batch (Avg. Loss 1.945, Accuracy 30.1): 100% 100/100 [00:02<00:00, 36.40it/s]
# test_batch (Avg. Loss 1.735, Accuracy 39.0): 100% 100/100 [00:00<00:00, 183.52it/s]
# --- EPOCH 2/100 ---
# train_batch (Avg. Loss 1.666, Accuracy 41.1): 100% 100/100 [00:02<00:00, 41.93it/s]
# test_batch (Avg. Loss 1.582, Accuracy 44.1): 100% 100/100 [00:00<00:00, 185.05it/s]
# --- EPOCH 3/100 ---
# train_batch (Avg. Loss 1.543, Accuracy 45.2): 100% 100/100 [00:02<00:00, 41.89it/s]
# test_batch (Avg. Loss 1.506, Accuracy 46.5): 100% 100/100 [00:00<00:00, 184.30it/s]
# --- EPOCH 4/100 ---
# train_batch (Avg. Loss 1.481, Accuracy 47.7): 100% 100/100 [00:02<00:00, 41.96it/s]
# test_batch (Avg. Loss 1.411, Accuracy 49.4): 100% 100/100 [00:00<00:00, 183.39it/s]
# --- EPOCH 5/100 ---
# train_batch (Avg. Loss 1.391, Accuracy 50.7): 100% 100/100 [00:02<00:00, 42.27it/s]
# test_batch (Avg. Loss 1.354, Accuracy 51.6): 100% 100/100 [00:00<00:00, 185.29it/s]
# --- EPOCH 6/100 ---
# train_batch (Avg. Loss 1.343, Accuracy 52.4): 100% 100/100 [00:02<00:00, 42.39it/s]
# test_batch (Avg. Loss 1.319, Accuracy 52.8): 100% 100/100 [00:00<00:00, 183.36it/s]
# --- EPOCH 7/100 ---
# train_batch (Avg. Loss 1.291, Accuracy 53.7): 100% 100/100 [00:02<00:00, 41.40it/s]
# test_batch (Avg. Loss 1.284, Accuracy 53.3): 100% 100/100 [00:00<00:00, 181.03it/s]
# --- EPOCH 8/100 ---
# train_batch (Avg. Loss 1.256, Accuracy 55.6): 100% 100/100 [00:02<00:00, 42.30it/s]
# test_batch (Avg. Loss 1.286, Accuracy 53.6): 100% 100/100 [00:00<00:00, 188.47it/s]
# --- EPOCH 9/100 ---
# train_batch (Avg. Loss 1.248, Accuracy 56.2): 100% 100/100 [00:02<00:00, 42.09it/s]
# test_batch (Avg. Loss 1.239, Accuracy 56.0): 100% 100/100 [00:00<00:00, 185.17it/s]
# --- EPOCH 10/100 ---
# train_batch (Avg. Loss 1.180, Accuracy 58.3): 100% 100/100 [00:02<00:00, 42.63it/s]
# test_batch (Avg. Loss 1.202, Accuracy 57.0): 100% 100/100 [00:00<00:00, 178.58it/s]
# --- EPOCH 11/100 ---
# train_batch (Avg. Loss 1.155, Accuracy 59.5): 100% 100/100 [00:02<00:00, 41.77it/s]
# test_batch (Avg. Loss 1.216, Accuracy 56.0): 100% 100/100 [00:00<00:00, 186.34it/s]
# --- EPOCH 12/100 ---
# train_batch (Avg. Loss 1.141, Accuracy 59.8): 100% 100/100 [00:02<00:00, 42.25it/s]
# test_batch (Avg. Loss 1.170, Accuracy 57.8): 100% 100/100 [00:00<00:00, 185.74it/s]
# --- EPOCH 13/100 ---
# train_batch (Avg. Loss 1.109, Accuracy 60.9): 100% 100/100 [00:02<00:00, 42.13it/s]
# test_batch (Avg. Loss 1.138, Accuracy 59.2): 100% 100/100 [00:00<00:00, 184.28it/s]
# --- EPOCH 14/100 ---
# train_batch (Avg. Loss 1.092, Accuracy 61.9): 100% 100/100 [00:02<00:00, 42.04it/s]
# test_batch (Avg. Loss 1.143, Accuracy 59.7): 100% 100/100 [00:00<00:00, 184.83it/s]
# --- EPOCH 15/100 ---
# train_batch (Avg. Loss 1.056, Accuracy 63.3): 100% 100/100 [00:02<00:00, 42.22it/s]
# test_batch (Avg. Loss 1.140, Accuracy 58.9): 100% 100/100 [00:00<00:00, 183.82it/s]
# --- EPOCH 16/100 ---
# train_batch (Avg. Loss 1.028, Accuracy 64.1): 100% 100/100 [00:02<00:00, 41.98it/s]
# test_batch (Avg. Loss 1.090, Accuracy 61.5): 100% 100/100 [00:00<00:00, 187.49it/s]
# --- EPOCH 17/100 ---
# train_batch (Avg. Loss 1.012, Accuracy 64.7): 100% 100/100 [00:02<00:00, 42.33it/s]
# test_batch (Avg. Loss 1.088, Accuracy 62.2): 100% 100/100 [00:00<00:00, 181.63it/s]
# --- EPOCH 18/100 ---
# train_batch (Avg. Loss 0.975, Accuracy 66.5): 100% 100/100 [00:02<00:00, 42.51it/s]
# test_batch (Avg. Loss 1.101, Accuracy 61.3): 100% 100/100 [00:00<00:00, 189.10it/s]
# --- EPOCH 19/100 ---
# train_batch (Avg. Loss 0.947, Accuracy 67.2): 100% 100/100 [00:02<00:00, 42.52it/s]
# test_batch (Avg. Loss 1.047, Accuracy 63.5): 100% 100/100 [00:00<00:00, 183.68it/s]
# --- EPOCH 20/100 ---
# train_batch (Avg. Loss 0.951, Accuracy 67.1): 100% 100/100 [00:02<00:00, 41.96it/s]
# test_batch (Avg. Loss 1.051, Accuracy 62.3): 100% 100/100 [00:00<00:00, 185.75it/s]
# --- EPOCH 21/100 ---
# train_batch (Avg. Loss 0.937, Accuracy 67.6): 100% 100/100 [00:02<00:00, 42.22it/s]
# test_batch (Avg. Loss 1.087, Accuracy 61.6): 100% 100/100 [00:00<00:00, 186.38it/s]
# --- EPOCH 22/100 ---
# train_batch (Avg. Loss 0.938, Accuracy 67.3): 100% 100/100 [00:02<00:00, 42.18it/s]
# test_batch (Avg. Loss 1.040, Accuracy 63.5): 100% 100/100 [00:00<00:00, 186.62it/s]
# *** Output file ./results/exp1_2_L4_K64_L4_K64.json written
# Running: python -m hw2.experiments run-exp --run-name exp1_2_L4_K128 --lr 0.0001 --filters-per-layer 128 --layers-per-block 4 --pool-every 4 --hidden-dims 1024 --model-type cnn
# *** Starting cnn_experiment with config:
# Namespace(run_name='exp1_2_L4_K128', out_dir='./results', seed=None, device=None, bs_train=128, bs_test=None, batches=100, epochs=100, early_stopping=3, checkpoints=None, lr=0.0001, reg=0.001, filters_per_layer=[128], layers_per_block=4, pool_every=4, hidden_dims=[1024], model_type='cnn')
# Files already downloaded and verified
# Files already downloaded and verified
# --- EPOCH 1/100 ---
# train_batch (Avg. Loss 1.864, Accuracy 33.7): 100% 100/100 [00:03<00:00, 30.39it/s]
# test_batch (Avg. Loss 1.639, Accuracy 42.9): 100% 100/100 [00:00<00:00, 175.94it/s]
# --- EPOCH 2/100 ---
# train_batch (Avg. Loss 1.556, Accuracy 45.5): 100% 100/100 [00:02<00:00, 34.43it/s]
# test_batch (Avg. Loss 1.452, Accuracy 48.2): 100% 100/100 [00:00<00:00, 175.37it/s]
# --- EPOCH 3/100 ---
# train_batch (Avg. Loss 1.402, Accuracy 50.1): 100% 100/100 [00:02<00:00, 34.33it/s]
# test_batch (Avg. Loss 1.358, Accuracy 51.4): 100% 100/100 [00:00<00:00, 175.89it/s]
# --- EPOCH 4/100 ---
# train_batch (Avg. Loss 1.302, Accuracy 53.8): 100% 100/100 [00:02<00:00, 33.74it/s]
# test_batch (Avg. Loss 1.315, Accuracy 52.7): 100% 100/100 [00:00<00:00, 174.36it/s]
# --- EPOCH 5/100 ---
# train_batch (Avg. Loss 1.239, Accuracy 55.9): 100% 100/100 [00:02<00:00, 33.92it/s]
# test_batch (Avg. Loss 1.253, Accuracy 54.6): 100% 100/100 [00:00<00:00, 176.77it/s]
# --- EPOCH 6/100 ---
# train_batch (Avg. Loss 1.189, Accuracy 57.8): 100% 100/100 [00:02<00:00, 34.81it/s]
# test_batch (Avg. Loss 1.238, Accuracy 56.1): 100% 100/100 [00:00<00:00, 174.12it/s]
# --- EPOCH 7/100 ---
# train_batch (Avg. Loss 1.153, Accuracy 59.9): 100% 100/100 [00:02<00:00, 34.31it/s]
# test_batch (Avg. Loss 1.160, Accuracy 58.9): 100% 100/100 [00:00<00:00, 176.33it/s]
# --- EPOCH 8/100 ---
# train_batch (Avg. Loss 1.094, Accuracy 61.8): 100% 100/100 [00:02<00:00, 34.46it/s]
# test_batch (Avg. Loss 1.148, Accuracy 59.4): 100% 100/100 [00:00<00:00, 177.26it/s]
# --- EPOCH 9/100 ---
# train_batch (Avg. Loss 1.044, Accuracy 63.5): 100% 100/100 [00:02<00:00, 34.72it/s]
# test_batch (Avg. Loss 1.116, Accuracy 60.7): 100% 100/100 [00:00<00:00, 174.35it/s]
# --- EPOCH 10/100 ---
# train_batch (Avg. Loss 1.000, Accuracy 64.8): 100% 100/100 [00:02<00:00, 34.13it/s]
# test_batch (Avg. Loss 1.058, Accuracy 61.9): 100% 100/100 [00:00<00:00, 172.42it/s]
# --- EPOCH 11/100 ---
# train_batch (Avg. Loss 0.988, Accuracy 66.0): 100% 100/100 [00:02<00:00, 34.41it/s]
# test_batch (Avg. Loss 1.062, Accuracy 62.3): 100% 100/100 [00:00<00:00, 174.68it/s]
# --- EPOCH 12/100 ---
# train_batch (Avg. Loss 0.949, Accuracy 67.3): 100% 100/100 [00:02<00:00, 34.54it/s]
# test_batch (Avg. Loss 1.041, Accuracy 63.7): 100% 100/100 [00:00<00:00, 176.45it/s]
# --- EPOCH 13/100 ---
# train_batch (Avg. Loss 0.931, Accuracy 68.0): 100% 100/100 [00:02<00:00, 34.68it/s]
# test_batch (Avg. Loss 1.020, Accuracy 63.6): 100% 100/100 [00:00<00:00, 176.04it/s]
# --- EPOCH 14/100 ---
# train_batch (Avg. Loss 0.914, Accuracy 68.6): 100% 100/100 [00:02<00:00, 33.88it/s]
# test_batch (Avg. Loss 1.055, Accuracy 62.9): 100% 100/100 [00:00<00:00, 176.67it/s]
# --- EPOCH 15/100 ---
# train_batch (Avg. Loss 0.904, Accuracy 68.7): 100% 100/100 [00:02<00:00, 34.38it/s]
# test_batch (Avg. Loss 1.011, Accuracy 63.3): 100% 100/100 [00:00<00:00, 178.33it/s]
# *** Output file ./results/exp1_2_L4_K128_L4_K128.json written
# Running: python -m hw2.experiments run-exp --run-name exp1_2_L8_K32 --lr 0.0001 --filters-per-layer 32 --layers-per-block 8 --pool-every 8 --hidden-dims 1024 --model-type cnn
# *** Starting cnn_experiment with config:
# Namespace(run_name='exp1_2_L8_K32', out_dir='./results', seed=None, device=None, bs_train=128, bs_test=None, batches=100, epochs=100, early_stopping=3, checkpoints=None, lr=0.0001, reg=0.001, filters_per_layer=[32], layers_per_block=8, pool_every=8, hidden_dims=[1024], model_type='cnn')
# Files already downloaded and verified
# Files already downloaded and verified
# --- EPOCH 1/100 ---
# train_batch (Avg. Loss 2.161, Accuracy 19.4): 100% 100/100 [00:03<00:00, 30.63it/s]
# test_batch (Avg. Loss 1.985, Accuracy 29.4): 100% 100/100 [00:00<00:00, 173.98it/s]
# --- EPOCH 2/100 ---
# train_batch (Avg. Loss 1.959, Accuracy 29.0): 100% 100/100 [00:02<00:00, 34.69it/s]
# test_batch (Avg. Loss 1.924, Accuracy 32.1): 100% 100/100 [00:00<00:00, 175.62it/s]
# --- EPOCH 3/100 ---
# train_batch (Avg. Loss 1.900, Accuracy 31.8): 100% 100/100 [00:02<00:00, 35.47it/s]
# test_batch (Avg. Loss 1.858, Accuracy 34.8): 100% 100/100 [00:00<00:00, 174.41it/s]
# --- EPOCH 4/100 ---
# train_batch (Avg. Loss 1.868, Accuracy 32.8): 100% 100/100 [00:02<00:00, 34.23it/s]
# test_batch (Avg. Loss 1.803, Accuracy 35.4): 100% 100/100 [00:00<00:00, 172.95it/s]
# --- EPOCH 5/100 ---
# train_batch (Avg. Loss 1.705, Accuracy 39.6): 100% 100/100 [00:02<00:00, 34.56it/s]
# test_batch (Avg. Loss 1.584, Accuracy 44.1): 100% 100/100 [00:00<00:00, 176.17it/s]
# --- EPOCH 6/100 ---
# train_batch (Avg. Loss 1.586, Accuracy 42.9): 100% 100/100 [00:02<00:00, 34.85it/s]
# test_batch (Avg. Loss 1.534, Accuracy 45.2): 100% 100/100 [00:00<00:00, 171.77it/s]
# --- EPOCH 7/100 ---
# train_batch (Avg. Loss 1.498, Accuracy 45.8): 100% 100/100 [00:02<00:00, 34.68it/s]
# test_batch (Avg. Loss 1.488, Accuracy 46.5): 100% 100/100 [00:00<00:00, 177.43it/s]
# --- EPOCH 8/100 ---
# train_batch (Avg. Loss 1.463, Accuracy 47.0): 100% 100/100 [00:02<00:00, 34.82it/s]
# test_batch (Avg. Loss 1.452, Accuracy 47.6): 100% 100/100 [00:00<00:00, 175.97it/s]
# --- EPOCH 9/100 ---
# train_batch (Avg. Loss 1.434, Accuracy 48.9): 100% 100/100 [00:02<00:00, 34.86it/s]
# test_batch (Avg. Loss 1.418, Accuracy 49.1): 100% 100/100 [00:00<00:00, 173.60it/s]
# --- EPOCH 10/100 ---
# train_batch (Avg. Loss 1.400, Accuracy 49.9): 100% 100/100 [00:02<00:00, 34.59it/s]
# test_batch (Avg. Loss 1.398, Accuracy 49.7): 100% 100/100 [00:00<00:00, 175.22it/s]
# --- EPOCH 11/100 ---
# train_batch (Avg. Loss 1.363, Accuracy 51.2): 100% 100/100 [00:02<00:00, 34.60it/s]
# test_batch (Avg. Loss 1.359, Accuracy 50.5): 100% 100/100 [00:00<00:00, 172.31it/s]
# --- EPOCH 12/100 ---
# train_batch (Avg. Loss 1.340, Accuracy 51.9): 100% 100/100 [00:02<00:00, 34.90it/s]
# test_batch (Avg. Loss 1.332, Accuracy 52.6): 100% 100/100 [00:00<00:00, 174.57it/s]
# --- EPOCH 13/100 ---
# train_batch (Avg. Loss 1.325, Accuracy 53.0): 100% 100/100 [00:02<00:00, 34.89it/s]
# test_batch (Avg. Loss 1.327, Accuracy 52.2): 100% 100/100 [00:00<00:00, 175.78it/s]
# --- EPOCH 14/100 ---
# train_batch (Avg. Loss 1.284, Accuracy 54.1): 100% 100/100 [00:02<00:00, 35.00it/s]
# test_batch (Avg. Loss 1.278, Accuracy 54.8): 100% 100/100 [00:00<00:00, 174.37it/s]
# --- EPOCH 15/100 ---
# train_batch (Avg. Loss 1.249, Accuracy 55.7): 100% 100/100 [00:02<00:00, 34.27it/s]
# test_batch (Avg. Loss 1.267, Accuracy 54.7): 100% 100/100 [00:00<00:00, 172.95it/s]
# --- EPOCH 16/100 ---
# train_batch (Avg. Loss 1.232, Accuracy 55.8): 100% 100/100 [00:02<00:00, 34.34it/s]
# test_batch (Avg. Loss 1.248, Accuracy 55.0): 100% 100/100 [00:00<00:00, 174.08it/s]
# --- EPOCH 17/100 ---
# train_batch (Avg. Loss 1.203, Accuracy 57.0): 100% 100/100 [00:02<00:00, 34.58it/s]
# test_batch (Avg. Loss 1.249, Accuracy 54.7): 100% 100/100 [00:00<00:00, 175.73it/s]
# --- EPOCH 18/100 ---
# train_batch (Avg. Loss 1.195, Accuracy 57.3): 100% 100/100 [00:02<00:00, 34.51it/s]
# test_batch (Avg. Loss 1.216, Accuracy 56.9): 100% 100/100 [00:00<00:00, 169.49it/s]
# --- EPOCH 19/100 ---
# train_batch (Avg. Loss 1.167, Accuracy 58.1): 100% 100/100 [00:02<00:00, 34.70it/s]
# test_batch (Avg. Loss 1.197, Accuracy 57.8): 100% 100/100 [00:00<00:00, 177.02it/s]
# --- EPOCH 20/100 ---
# train_batch (Avg. Loss 1.154, Accuracy 58.6): 100% 100/100 [00:02<00:00, 35.04it/s]
# test_batch (Avg. Loss 1.209, Accuracy 57.0): 100% 100/100 [00:00<00:00, 176.53it/s]
# --- EPOCH 21/100 ---
# train_batch (Avg. Loss 1.128, Accuracy 60.5): 100% 100/100 [00:02<00:00, 34.69it/s]
# test_batch (Avg. Loss 1.181, Accuracy 57.8): 100% 100/100 [00:00<00:00, 173.19it/s]
# --- EPOCH 22/100 ---
# train_batch (Avg. Loss 1.111, Accuracy 60.4): 100% 100/100 [00:02<00:00, 34.15it/s]
# test_batch (Avg. Loss 1.167, Accuracy 58.4): 100% 100/100 [00:00<00:00, 175.17it/s]
# --- EPOCH 23/100 ---
# train_batch (Avg. Loss 1.094, Accuracy 61.1): 100% 100/100 [00:02<00:00, 34.67it/s]
# test_batch (Avg. Loss 1.140, Accuracy 59.7): 100% 100/100 [00:00<00:00, 175.18it/s]
# --- EPOCH 24/100 ---
# train_batch (Avg. Loss 1.080, Accuracy 61.8): 100% 100/100 [00:02<00:00, 34.70it/s]
# test_batch (Avg. Loss 1.123, Accuracy 59.8): 100% 100/100 [00:00<00:00, 172.18it/s]
# --- EPOCH 25/100 ---
# train_batch (Avg. Loss 1.062, Accuracy 62.4): 100% 100/100 [00:02<00:00, 34.94it/s]
# test_batch (Avg. Loss 1.155, Accuracy 58.9): 100% 100/100 [00:00<00:00, 172.01it/s]
# --- EPOCH 26/100 ---
# train_batch (Avg. Loss 1.058, Accuracy 62.5): 100% 100/100 [00:02<00:00, 34.81it/s]
# test_batch (Avg. Loss 1.137, Accuracy 59.3): 100% 100/100 [00:00<00:00, 173.24it/s]
# --- EPOCH 27/100 ---
# train_batch (Avg. Loss 1.051, Accuracy 63.0): 100% 100/100 [00:02<00:00, 34.77it/s]
# test_batch (Avg. Loss 1.114, Accuracy 60.6): 100% 100/100 [00:00<00:00, 173.86it/s]
# --- EPOCH 28/100 ---
# train_batch (Avg. Loss 1.032, Accuracy 64.0): 100% 100/100 [00:02<00:00, 34.77it/s]
# test_batch (Avg. Loss 1.114, Accuracy 60.0): 100% 100/100 [00:00<00:00, 174.48it/s]
# --- EPOCH 29/100 ---
# train_batch (Avg. Loss 1.004, Accuracy 64.0): 100% 100/100 [00:02<00:00, 35.01it/s]
# test_batch (Avg. Loss 1.135, Accuracy 59.6): 100% 100/100 [00:00<00:00, 173.22it/s]
# --- EPOCH 30/100 ---
# train_batch (Avg. Loss 0.987, Accuracy 65.2): 100% 100/100 [00:02<00:00, 34.60it/s]
# test_batch (Avg. Loss 1.106, Accuracy 61.5): 100% 100/100 [00:00<00:00, 173.02it/s]
# --- EPOCH 31/100 ---
# train_batch (Avg. Loss 0.976, Accuracy 65.4): 100% 100/100 [00:02<00:00, 34.87it/s]
# test_batch (Avg. Loss 1.109, Accuracy 60.6): 100% 100/100 [00:00<00:00, 177.30it/s]
# --- EPOCH 32/100 ---
# train_batch (Avg. Loss 0.977, Accuracy 65.7): 100% 100/100 [00:02<00:00, 35.04it/s]
# test_batch (Avg. Loss 1.104, Accuracy 60.5): 100% 100/100 [00:00<00:00, 173.93it/s]
# --- EPOCH 33/100 ---
# train_batch (Avg. Loss 0.977, Accuracy 65.9): 100% 100/100 [00:02<00:00, 34.89it/s]
# test_batch (Avg. Loss 1.083, Accuracy 61.5): 100% 100/100 [00:00<00:00, 172.53it/s]
# *** Output file ./results/exp1_2_L8_K32_L8_K32.json written
# Running: python -m hw2.experiments run-exp --run-name exp1_2_L8_K64 --lr 0.0001 --filters-per-layer 64 --layers-per-block 8 --pool-every 8 --hidden-dims 1024 --model-type cnn
# *** Starting cnn_experiment with config:
# Namespace(run_name='exp1_2_L8_K64', out_dir='./results', seed=None, device=None, bs_train=128, bs_test=None, batches=100, epochs=100, early_stopping=3, checkpoints=None, lr=0.0001, reg=0.001, filters_per_layer=[64], layers_per_block=8, pool_every=8, hidden_dims=[1024], model_type='cnn')
# Files already downloaded and verified
# Files already downloaded and verified
# --- EPOCH 1/100 ---
# train_batch (Avg. Loss 2.111, Accuracy 22.0): 100% 100/100 [00:03<00:00, 31.31it/s]
# test_batch (Avg. Loss 1.925, Accuracy 32.5): 100% 100/100 [00:00<00:00, 166.41it/s]
# --- EPOCH 2/100 ---
# train_batch (Avg. Loss 1.814, Accuracy 35.8): 100% 100/100 [00:02<00:00, 35.00it/s]
# test_batch (Avg. Loss 1.680, Accuracy 41.5): 100% 100/100 [00:00<00:00, 172.82it/s]
# --- EPOCH 3/100 ---
# train_batch (Avg. Loss 1.657, Accuracy 40.7): 100% 100/100 [00:02<00:00, 35.52it/s]
# test_batch (Avg. Loss 1.609, Accuracy 42.5): 100% 100/100 [00:00<00:00, 172.75it/s]
# --- EPOCH 4/100 ---
# train_batch (Avg. Loss 1.583, Accuracy 43.2): 100% 100/100 [00:02<00:00, 35.74it/s]
# test_batch (Avg. Loss 1.516, Accuracy 44.7): 100% 100/100 [00:00<00:00, 172.11it/s]
# --- EPOCH 5/100 ---
# train_batch (Avg. Loss 1.495, Accuracy 47.4): 100% 100/100 [00:02<00:00, 34.80it/s]
# test_batch (Avg. Loss 1.484, Accuracy 46.5): 100% 100/100 [00:00<00:00, 165.41it/s]
# --- EPOCH 6/100 ---
# train_batch (Avg. Loss 1.440, Accuracy 48.7): 100% 100/100 [00:02<00:00, 35.18it/s]
# test_batch (Avg. Loss 1.374, Accuracy 51.5): 100% 100/100 [00:00<00:00, 171.88it/s]
# --- EPOCH 7/100 ---
# train_batch (Avg. Loss 1.381, Accuracy 50.5): 100% 100/100 [00:02<00:00, 35.56it/s]
# test_batch (Avg. Loss 1.355, Accuracy 51.5): 100% 100/100 [00:00<00:00, 171.23it/s]
# --- EPOCH 8/100 ---
# train_batch (Avg. Loss 1.339, Accuracy 52.5): 100% 100/100 [00:02<00:00, 35.68it/s]
# test_batch (Avg. Loss 1.324, Accuracy 52.5): 100% 100/100 [00:00<00:00, 168.14it/s]
# --- EPOCH 9/100 ---
# train_batch (Avg. Loss 1.276, Accuracy 54.7): 100% 100/100 [00:02<00:00, 35.35it/s]
# test_batch (Avg. Loss 1.311, Accuracy 52.9): 100% 100/100 [00:00<00:00, 171.17it/s]
# --- EPOCH 10/100 ---
# train_batch (Avg. Loss 1.251, Accuracy 56.3): 100% 100/100 [00:02<00:00, 35.61it/s]
# test_batch (Avg. Loss 1.307, Accuracy 53.8): 100% 100/100 [00:00<00:00, 172.47it/s]
# --- EPOCH 11/100 ---
# train_batch (Avg. Loss 1.223, Accuracy 56.8): 100% 100/100 [00:02<00:00, 35.66it/s]
# test_batch (Avg. Loss 1.245, Accuracy 55.8): 100% 100/100 [00:00<00:00, 171.42it/s]
# --- EPOCH 12/100 ---
# train_batch (Avg. Loss 1.178, Accuracy 57.9): 100% 100/100 [00:02<00:00, 35.87it/s]
# test_batch (Avg. Loss 1.202, Accuracy 57.2): 100% 100/100 [00:00<00:00, 169.38it/s]
# --- EPOCH 13/100 ---
# train_batch (Avg. Loss 1.146, Accuracy 60.0): 100% 100/100 [00:02<00:00, 35.39it/s]
# test_batch (Avg. Loss 1.171, Accuracy 59.1): 100% 100/100 [00:00<00:00, 174.02it/s]
# --- EPOCH 14/100 ---
# train_batch (Avg. Loss 1.111, Accuracy 61.2): 100% 100/100 [00:02<00:00, 35.62it/s]
# test_batch (Avg. Loss 1.166, Accuracy 59.0): 100% 100/100 [00:00<00:00, 171.26it/s]
# --- EPOCH 15/100 ---
# train_batch (Avg. Loss 1.082, Accuracy 62.6): 100% 100/100 [00:02<00:00, 35.70it/s]
# test_batch (Avg. Loss 1.149, Accuracy 59.6): 100% 100/100 [00:00<00:00, 173.20it/s]
# --- EPOCH 16/100 ---
# train_batch (Avg. Loss 1.048, Accuracy 63.2): 100% 100/100 [00:02<00:00, 35.82it/s]
# test_batch (Avg. Loss 1.111, Accuracy 60.4): 100% 100/100 [00:00<00:00, 169.34it/s]
# --- EPOCH 17/100 ---
# train_batch (Avg. Loss 1.034, Accuracy 63.9): 100% 100/100 [00:02<00:00, 35.22it/s]
# test_batch (Avg. Loss 1.085, Accuracy 62.0): 100% 100/100 [00:00<00:00, 173.58it/s]
# --- EPOCH 18/100 ---
# train_batch (Avg. Loss 0.998, Accuracy 65.3): 100% 100/100 [00:02<00:00, 35.74it/s]
# test_batch (Avg. Loss 1.057, Accuracy 62.3): 100% 100/100 [00:00<00:00, 172.91it/s]
# --- EPOCH 19/100 ---
# train_batch (Avg. Loss 0.984, Accuracy 65.9): 100% 100/100 [00:02<00:00, 35.74it/s]
# test_batch (Avg. Loss 1.076, Accuracy 61.3): 100% 100/100 [00:00<00:00, 172.75it/s]
# --- EPOCH 20/100 ---
# train_batch (Avg. Loss 0.949, Accuracy 66.8): 100% 100/100 [00:02<00:00, 34.87it/s]
# test_batch (Avg. Loss 1.042, Accuracy 63.1): 100% 100/100 [00:00<00:00, 172.47it/s]
# --- EPOCH 21/100 ---
# train_batch (Avg. Loss 0.942, Accuracy 66.8): 100% 100/100 [00:02<00:00, 35.66it/s]
# test_batch (Avg. Loss 1.048, Accuracy 63.2): 100% 100/100 [00:00<00:00, 172.14it/s]
# --- EPOCH 22/100 ---
# train_batch (Avg. Loss 0.927, Accuracy 67.7): 100% 100/100 [00:02<00:00, 35.60it/s]
# test_batch (Avg. Loss 1.050, Accuracy 63.5): 100% 100/100 [00:00<00:00, 174.28it/s]
# --- EPOCH 23/100 ---
# train_batch (Avg. Loss 0.904, Accuracy 68.7): 100% 100/100 [00:02<00:00, 35.56it/s]
# test_batch (Avg. Loss 1.034, Accuracy 63.9): 100% 100/100 [00:00<00:00, 166.48it/s]
# --- EPOCH 24/100 ---
# train_batch (Avg. Loss 0.890, Accuracy 69.0): 100% 100/100 [00:02<00:00, 34.93it/s]
# test_batch (Avg. Loss 1.033, Accuracy 63.3): 100% 100/100 [00:00<00:00, 171.23it/s]
# --- EPOCH 25/100 ---
# train_batch (Avg. Loss 0.875, Accuracy 69.4): 100% 100/100 [00:02<00:00, 35.66it/s]
# test_batch (Avg. Loss 1.016, Accuracy 64.8): 100% 100/100 [00:00<00:00, 171.16it/s]
# --- EPOCH 26/100 ---
# train_batch (Avg. Loss 0.862, Accuracy 69.6): 100% 100/100 [00:02<00:00, 35.75it/s]
# test_batch (Avg. Loss 1.040, Accuracy 63.2): 100% 100/100 [00:00<00:00, 173.31it/s]
# --- EPOCH 27/100 ---
# train_batch (Avg. Loss 0.825, Accuracy 71.6): 100% 100/100 [00:02<00:00, 35.80it/s]
# test_batch (Avg. Loss 1.005, Accuracy 64.8): 100% 100/100 [00:00<00:00, 172.46it/s]
# --- EPOCH 28/100 ---
# train_batch (Avg. Loss 0.832, Accuracy 71.3): 100% 100/100 [00:02<00:00, 35.77it/s]
# test_batch (Avg. Loss 1.018, Accuracy 64.4): 100% 100/100 [00:00<00:00, 173.00it/s]
# --- EPOCH 29/100 ---
# train_batch (Avg. Loss 0.800, Accuracy 72.2): 100% 100/100 [00:02<00:00, 35.72it/s]
# test_batch (Avg. Loss 1.019, Accuracy 64.7): 100% 100/100 [00:00<00:00, 173.80it/s]
# --- EPOCH 30/100 ---
# train_batch (Avg. Loss 0.801, Accuracy 72.3): 100% 100/100 [00:02<00:00, 36.01it/s]
# test_batch (Avg. Loss 1.021, Accuracy 65.1): 100% 100/100 [00:00<00:00, 173.81it/s]
# --- EPOCH 31/100 ---
# train_batch (Avg. Loss 0.784, Accuracy 72.9): 100% 100/100 [00:02<00:00, 35.48it/s]
# test_batch (Avg. Loss 0.992, Accuracy 65.6): 100% 100/100 [00:00<00:00, 171.10it/s]
# --- EPOCH 32/100 ---
# train_batch (Avg. Loss 0.771, Accuracy 73.4): 100% 100/100 [00:02<00:00, 35.44it/s]
# test_batch (Avg. Loss 0.999, Accuracy 65.4): 100% 100/100 [00:00<00:00, 173.53it/s]
# --- EPOCH 33/100 ---
# train_batch (Avg. Loss 0.758, Accuracy 73.9): 100% 100/100 [00:02<00:00, 35.39it/s]
# test_batch (Avg. Loss 1.001, Accuracy 65.6): 100% 100/100 [00:00<00:00, 172.31it/s]
# --- EPOCH 34/100 ---
# train_batch (Avg. Loss 0.752, Accuracy 73.9): 100% 100/100 [00:02<00:00, 35.33it/s]
# test_batch (Avg. Loss 0.998, Accuracy 64.6): 100% 100/100 [00:00<00:00, 165.28it/s]
# --- EPOCH 35/100 ---
# train_batch (Avg. Loss 0.735, Accuracy 74.9): 100% 100/100 [00:02<00:00, 35.42it/s]
# test_batch (Avg. Loss 1.008, Accuracy 65.3): 100% 100/100 [00:00<00:00, 174.32it/s]
# --- EPOCH 36/100 ---
# train_batch (Avg. Loss 0.706, Accuracy 75.6): 100% 100/100 [00:02<00:00, 35.24it/s]
# test_batch (Avg. Loss 1.016, Accuracy 65.3): 100% 100/100 [00:00<00:00, 172.75it/s]
# *** Output file ./results/exp1_2_L8_K64_L8_K64.json written
# Running: python -m hw2.experiments run-exp --run-name exp1_2_L8_K128 --lr 0.0001 --filters-per-layer 128 --layers-per-block 8 --pool-every 8 --hidden-dims 1024 --model-type cnn
# *** Starting cnn_experiment with config:
# Namespace(run_name='exp1_2_L8_K128', out_dir='./results', seed=None, device=None, bs_train=128, bs_test=None, batches=100, epochs=100, early_stopping=3, checkpoints=None, lr=0.0001, reg=0.001, filters_per_layer=[128], layers_per_block=8, pool_every=8, hidden_dims=[1024], model_type='cnn')
# Files already downloaded and verified
# Files already downloaded and verified
# --- EPOCH 1/100 ---
# train_batch (Avg. Loss 2.079, Accuracy 23.6): 100% 100/100 [00:04<00:00, 24.48it/s]
# test_batch (Avg. Loss 1.919, Accuracy 31.5): 100% 100/100 [00:00<00:00, 159.70it/s]
# --- EPOCH 2/100 ---
# train_batch (Avg. Loss 1.761, Accuracy 36.8): 100% 100/100 [00:03<00:00, 27.50it/s]
# test_batch (Avg. Loss 1.618, Accuracy 41.4): 100% 100/100 [00:00<00:00, 160.43it/s]
# --- EPOCH 3/100 ---
# train_batch (Avg. Loss 1.542, Accuracy 44.8): 100% 100/100 [00:03<00:00, 27.08it/s]
# test_batch (Avg. Loss 1.463, Accuracy 47.9): 100% 100/100 [00:00<00:00, 159.11it/s]
# --- EPOCH 4/100 ---
# train_batch (Avg. Loss 1.419, Accuracy 48.8): 100% 100/100 [00:03<00:00, 27.22it/s]
# test_batch (Avg. Loss 1.384, Accuracy 50.8): 100% 100/100 [00:00<00:00, 161.89it/s]
# --- EPOCH 5/100 ---
# train_batch (Avg. Loss 1.337, Accuracy 51.8): 100% 100/100 [00:03<00:00, 27.27it/s]
# test_batch (Avg. Loss 1.308, Accuracy 52.2): 100% 100/100 [00:00<00:00, 156.81it/s]
# --- EPOCH 6/100 ---
# train_batch (Avg. Loss 1.283, Accuracy 54.7): 100% 100/100 [00:03<00:00, 27.12it/s]
# test_batch (Avg. Loss 1.285, Accuracy 53.6): 100% 100/100 [00:00<00:00, 162.08it/s]
# --- EPOCH 7/100 ---
# train_batch (Avg. Loss 1.208, Accuracy 57.4): 100% 100/100 [00:03<00:00, 27.44it/s]
# test_batch (Avg. Loss 1.198, Accuracy 58.7): 100% 100/100 [00:00<00:00, 160.39it/s]
# --- EPOCH 8/100 ---
# train_batch (Avg. Loss 1.163, Accuracy 59.1): 100% 100/100 [00:03<00:00, 27.21it/s]
# test_batch (Avg. Loss 1.185, Accuracy 57.7): 100% 100/100 [00:00<00:00, 160.79it/s]
# --- EPOCH 9/100 ---
# train_batch (Avg. Loss 1.094, Accuracy 61.7): 100% 100/100 [00:03<00:00, 27.07it/s]
# test_batch (Avg. Loss 1.123, Accuracy 60.6): 100% 100/100 [00:00<00:00, 160.12it/s]
# --- EPOCH 10/100 ---
# train_batch (Avg. Loss 1.042, Accuracy 63.4): 100% 100/100 [00:03<00:00, 27.23it/s]
# test_batch (Avg. Loss 1.105, Accuracy 60.6): 100% 100/100 [00:00<00:00, 159.03it/s]
# --- EPOCH 11/100 ---
# train_batch (Avg. Loss 0.995, Accuracy 65.4): 100% 100/100 [00:03<00:00, 27.32it/s]
# test_batch (Avg. Loss 1.045, Accuracy 64.2): 100% 100/100 [00:00<00:00, 159.36it/s]
# --- EPOCH 12/100 ---
# train_batch (Avg. Loss 0.981, Accuracy 65.7): 100% 100/100 [00:03<00:00, 26.91it/s]
# test_batch (Avg. Loss 1.044, Accuracy 63.5): 100% 100/100 [00:00<00:00, 159.13it/s]
# --- EPOCH 13/100 ---
# train_batch (Avg. Loss 0.943, Accuracy 67.1): 100% 100/100 [00:03<00:00, 27.27it/s]
# test_batch (Avg. Loss 1.037, Accuracy 63.1): 100% 100/100 [00:00<00:00, 162.17it/s]
# --- EPOCH 14/100 ---
# train_batch (Avg. Loss 0.931, Accuracy 67.4): 100% 100/100 [00:03<00:00, 27.23it/s]
# test_batch (Avg. Loss 1.051, Accuracy 63.4): 100% 100/100 [00:00<00:00, 157.42it/s]
# *** Output file ./results/exp1_2_L8_K128_L8_K128.json written

# %%
plot_exp_results('exp1_2_L2*.json')
# Out:
# common config:  {'run_name': 'exp1_2_L2_K64', 'out_dir': './results', 'seed': 71951712, 'device': None, 'bs_train': 128, 'bs_test': 32, 'batches': 100, 'epochs': 100, 'early_stopping': 3, 'checkpoints': None, 'lr': 0.0001, 'reg': 0.001, 'pool_every': 2, 'hidden_dims': [1024], 'model_type': 'cnn', 'activation_type': 'lrelu', 'activation_params': {'negative_slope': 0.5}, 'conv_params': {'kernel_size': 3, 'stride': 1, 'padding': 1}, 'pooling_type': 'max', 'pooling_params': {'kernel_size': 2, 'stride': 2}, 'batchnorm': True, 'dropout': 0.2, 'kw': {}}

# %%
plot_exp_results('exp1_2_L4*.json')
# Out:
# common config:  {'run_name': 'exp1_2_L4_K64', 'out_dir': './results', 'seed': 1681796669, 'device': None, 'bs_train': 128, 'bs_test': 32, 'batches': 100, 'epochs': 100, 'early_stopping': 3, 'checkpoints': None, 'lr': 0.0001, 'reg': 0.001, 'pool_every': 4, 'hidden_dims': [1024], 'model_type': 'cnn', 'activation_type': 'lrelu', 'activation_params': {'negative_slope': 0.5}, 'conv_params': {'kernel_size': 3, 'stride': 1, 'padding': 1}, 'pooling_type': 'max', 'pooling_params': {'kernel_size': 2, 'stride': 2}, 'batchnorm': True, 'dropout': 0.2, 'kw': {}}

# %%
plot_exp_results('exp1_2_L8*.json')
# Out:
# common config:  {'run_name': 'exp1_2_L8_K64', 'out_dir': './results', 'seed': 1031357993, 'device': None, 'bs_train': 128, 'bs_test': 32, 'batches': 100, 'epochs': 100, 'early_stopping': 3, 'checkpoints': None, 'lr': 0.0001, 'reg': 0.001, 'pool_every': 8, 'hidden_dims': [1024], 'model_type': 'cnn', 'activation_type': 'lrelu', 'activation_params': {'negative_slope': 0.5}, 'conv_params': {'kernel_size': 3, 'stride': 1, 'padding': 1}, 'pooling_type': 'max', 'pooling_params': {'kernel_size': 2, 'stride': 2}, 'batchnorm': True, 'dropout': 0.2, 'kw': {}}

# %% [markdown]
# #### Experiment 1.3: Varying both the number of filters (`K`) and network depth (`L`)

# %% [markdown]
# Now we'll test the effect of the number of convolutional filters in each layer.
#
# **Configuratons**:
# - `K=[64, 128]` fixed with `L=2,3,4` varying per run.
#
# So 3 different runs in total. To clarify, each run `K` takes the value of an array with a two elements.
#
# **Naming runs**:
# Each run should be named `exp1_3_L{}_K{}-{}` where the braces are placeholders for the values. For example, the first run should be named `exp1_3_L2_K64-128`.

# %% [markdown]
# **TODO**: Run the experiment on the above configuration  with the `CNN` model. Make sure the result file names are as expected. Use the following blocks to display the results.

# %%
from hw2.experiments import cnn_experiment

filters_per_layer = [64, 128]
layers_per_block_list = [2, 3, 4]



hidden_dims = 1024


for L in layers_per_block_list:
    lr = 1e-4
    run_name = f"exp1_3_L{L}_K{filters_per_layer[0]}-{filters_per_layer[1]}"
    command = (
        f"python -m hw2.experiments run-exp "
        f"--run-name {run_name} "
        f"--lr {lr} "
        f"--filters-per-layer {filters_per_layer[0]} {filters_per_layer[1]} "
        f"--layers-per-block {L} "
        f"--pool-every {L} "
        f"--hidden-dims {hidden_dims} "
        f"--model-type cnn "
    )
    print(f"Running: {command}")
    # os.system(command)
    # !{command}
# Out:
# Running: python -m hw2.experiments run-exp --run-name exp1_3_L2_K64-128 --lr 0.0001 --filters-per-layer 64 128 --layers-per-block 2 --pool-every 2 --hidden-dims 1024 --model-type cnn
# *** Starting cnn_experiment with config:
# Namespace(run_name='exp1_3_L2_K64-128', out_dir='./results', seed=None, device=None, bs_train=128, bs_test=None, batches=100, epochs=100, early_stopping=3, checkpoints=None, lr=0.0001, reg=0.001, filters_per_layer=[64, 128], layers_per_block=2, pool_every=2, hidden_dims=[1024], model_type='cnn')
# Files already downloaded and verified
# Files already downloaded and verified
# --- EPOCH 1/100 ---
# train_batch (Avg. Loss 1.988, Accuracy 28.1): 100% 100/100 [00:02<00:00, 38.63it/s]
# test_batch (Avg. Loss 1.759, Accuracy 39.8): 100% 100/100 [00:00<00:00, 181.41it/s]
# --- EPOCH 2/100 ---
# train_batch (Avg. Loss 1.668, Accuracy 41.4): 100% 100/100 [00:02<00:00, 45.39it/s]
# test_batch (Avg. Loss 1.567, Accuracy 44.3): 100% 100/100 [00:00<00:00, 184.49it/s]
# --- EPOCH 3/100 ---
# train_batch (Avg. Loss 1.540, Accuracy 45.0): 100% 100/100 [00:02<00:00, 45.80it/s]
# test_batch (Avg. Loss 1.493, Accuracy 46.9): 100% 100/100 [00:00<00:00, 185.76it/s]
# --- EPOCH 4/100 ---
# train_batch (Avg. Loss 1.446, Accuracy 48.8): 100% 100/100 [00:02<00:00, 46.05it/s]
# test_batch (Avg. Loss 1.401, Accuracy 50.1): 100% 100/100 [00:00<00:00, 186.60it/s]
# --- EPOCH 5/100 ---
# train_batch (Avg. Loss 1.402, Accuracy 50.0): 100% 100/100 [00:02<00:00, 45.69it/s]
# test_batch (Avg. Loss 1.349, Accuracy 53.0): 100% 100/100 [00:00<00:00, 180.25it/s]
# --- EPOCH 6/100 ---
# train_batch (Avg. Loss 1.350, Accuracy 52.1): 100% 100/100 [00:02<00:00, 45.02it/s]
# test_batch (Avg. Loss 1.360, Accuracy 51.8): 100% 100/100 [00:00<00:00, 185.68it/s]
# --- EPOCH 7/100 ---
# train_batch (Avg. Loss 1.310, Accuracy 53.6): 100% 100/100 [00:02<00:00, 45.59it/s]
# test_batch (Avg. Loss 1.300, Accuracy 54.5): 100% 100/100 [00:00<00:00, 185.50it/s]
# --- EPOCH 8/100 ---
# train_batch (Avg. Loss 1.260, Accuracy 55.4): 100% 100/100 [00:02<00:00, 46.09it/s]
# test_batch (Avg. Loss 1.260, Accuracy 54.8): 100% 100/100 [00:00<00:00, 185.66it/s]
# --- EPOCH 9/100 ---
# train_batch (Avg. Loss 1.216, Accuracy 57.0): 100% 100/100 [00:02<00:00, 46.01it/s]
# test_batch (Avg. Loss 1.236, Accuracy 55.6): 100% 100/100 [00:00<00:00, 185.52it/s]
# --- EPOCH 10/100 ---
# train_batch (Avg. Loss 1.187, Accuracy 58.2): 100% 100/100 [00:02<00:00, 45.80it/s]
# test_batch (Avg. Loss 1.204, Accuracy 57.7): 100% 100/100 [00:00<00:00, 185.82it/s]
# --- EPOCH 11/100 ---
# train_batch (Avg. Loss 1.154, Accuracy 59.4): 100% 100/100 [00:02<00:00, 45.56it/s]
# test_batch (Avg. Loss 1.146, Accuracy 59.2): 100% 100/100 [00:00<00:00, 184.58it/s]
# --- EPOCH 12/100 ---
# train_batch (Avg. Loss 1.124, Accuracy 60.3): 100% 100/100 [00:02<00:00, 45.94it/s]
# test_batch (Avg. Loss 1.121, Accuracy 60.3): 100% 100/100 [00:00<00:00, 186.29it/s]
# --- EPOCH 13/100 ---
# train_batch (Avg. Loss 1.107, Accuracy 61.1): 100% 100/100 [00:02<00:00, 45.76it/s]
# test_batch (Avg. Loss 1.151, Accuracy 58.8): 100% 100/100 [00:00<00:00, 186.13it/s]
# --- EPOCH 14/100 ---
# train_batch (Avg. Loss 1.098, Accuracy 61.5): 100% 100/100 [00:02<00:00, 46.05it/s]
# test_batch (Avg. Loss 1.093, Accuracy 61.7): 100% 100/100 [00:00<00:00, 189.05it/s]
# --- EPOCH 15/100 ---
# train_batch (Avg. Loss 1.056, Accuracy 62.9): 100% 100/100 [00:02<00:00, 45.48it/s]
# test_batch (Avg. Loss 1.067, Accuracy 62.9): 100% 100/100 [00:00<00:00, 177.52it/s]
# --- EPOCH 16/100 ---
# train_batch (Avg. Loss 1.038, Accuracy 63.5): 100% 100/100 [00:02<00:00, 45.22it/s]
# test_batch (Avg. Loss 1.059, Accuracy 62.3): 100% 100/100 [00:00<00:00, 185.69it/s]
# --- EPOCH 17/100 ---
# train_batch (Avg. Loss 1.032, Accuracy 64.0): 100% 100/100 [00:02<00:00, 45.75it/s]
# test_batch (Avg. Loss 1.060, Accuracy 62.2): 100% 100/100 [00:00<00:00, 183.25it/s]
# --- EPOCH 18/100 ---
# train_batch (Avg. Loss 1.006, Accuracy 65.1): 100% 100/100 [00:02<00:00, 46.10it/s]
# test_batch (Avg. Loss 1.057, Accuracy 63.2): 100% 100/100 [00:00<00:00, 187.48it/s]
# --- EPOCH 19/100 ---
# train_batch (Avg. Loss 0.967, Accuracy 66.2): 100% 100/100 [00:02<00:00, 45.88it/s]
# test_batch (Avg. Loss 1.005, Accuracy 65.1): 100% 100/100 [00:00<00:00, 187.12it/s]
# --- EPOCH 20/100 ---
# train_batch (Avg. Loss 0.965, Accuracy 66.3): 100% 100/100 [00:02<00:00, 45.35it/s]
# test_batch (Avg. Loss 0.993, Accuracy 65.3): 100% 100/100 [00:00<00:00, 183.56it/s]
# --- EPOCH 21/100 ---
# train_batch (Avg. Loss 0.943, Accuracy 67.5): 100% 100/100 [00:02<00:00, 45.41it/s]
# test_batch (Avg. Loss 0.984, Accuracy 66.0): 100% 100/100 [00:00<00:00, 183.98it/s]
# --- EPOCH 22/100 ---
# train_batch (Avg. Loss 0.945, Accuracy 67.1): 100% 100/100 [00:02<00:00, 45.61it/s]
# test_batch (Avg. Loss 0.966, Accuracy 65.8): 100% 100/100 [00:00<00:00, 179.71it/s]
# --- EPOCH 23/100 ---
# train_batch (Avg. Loss 0.915, Accuracy 68.1): 100% 100/100 [00:02<00:00, 45.43it/s]
# test_batch (Avg. Loss 0.983, Accuracy 64.8): 100% 100/100 [00:00<00:00, 186.87it/s]
# --- EPOCH 24/100 ---
# train_batch (Avg. Loss 0.914, Accuracy 68.2): 100% 100/100 [00:02<00:00, 45.43it/s]
# test_batch (Avg. Loss 0.980, Accuracy 65.8): 100% 100/100 [00:00<00:00, 181.87it/s]
# *** Output file ./results/exp1_3_L2_K64-128_L2_K64-128.json written
# Running: python -m hw2.experiments run-exp --run-name exp1_3_L3_K64-128 --lr 0.0001 --filters-per-layer 64 128 --layers-per-block 3 --pool-every 3 --hidden-dims 1024 --model-type cnn
# *** Starting cnn_experiment with config:
# Namespace(run_name='exp1_3_L3_K64-128', out_dir='./results', seed=None, device=None, bs_train=128, bs_test=None, batches=100, epochs=100, early_stopping=3, checkpoints=None, lr=0.0001, reg=0.001, filters_per_layer=[64, 128], layers_per_block=3, pool_every=3, hidden_dims=[1024], model_type='cnn')
# Files already downloaded and verified
# Files already downloaded and verified
# --- EPOCH 1/100 ---
# train_batch (Avg. Loss 2.064, Accuracy 24.3): 100% 100/100 [00:02<00:00, 35.94it/s]
# test_batch (Avg. Loss 1.852, Accuracy 34.3): 100% 100/100 [00:00<00:00, 171.55it/s]
# --- EPOCH 2/100 ---
# train_batch (Avg. Loss 1.731, Accuracy 38.7): 100% 100/100 [00:02<00:00, 41.08it/s]
# test_batch (Avg. Loss 1.629, Accuracy 42.0): 100% 100/100 [00:00<00:00, 178.62it/s]
# --- EPOCH 3/100 ---
# train_batch (Avg. Loss 1.585, Accuracy 43.5): 100% 100/100 [00:02<00:00, 42.30it/s]
# test_batch (Avg. Loss 1.498, Accuracy 46.4): 100% 100/100 [00:00<00:00, 179.33it/s]
# --- EPOCH 4/100 ---
# train_batch (Avg. Loss 1.489, Accuracy 46.4): 100% 100/100 [00:02<00:00, 42.31it/s]
# test_batch (Avg. Loss 1.437, Accuracy 47.7): 100% 100/100 [00:00<00:00, 179.47it/s]
# --- EPOCH 5/100 ---
# train_batch (Avg. Loss 1.415, Accuracy 48.7): 100% 100/100 [00:02<00:00, 42.12it/s]
# test_batch (Avg. Loss 1.396, Accuracy 50.0): 100% 100/100 [00:00<00:00, 176.88it/s]
# --- EPOCH 6/100 ---
# train_batch (Avg. Loss 1.363, Accuracy 51.4): 100% 100/100 [00:02<00:00, 41.85it/s]
# test_batch (Avg. Loss 1.338, Accuracy 51.9): 100% 100/100 [00:00<00:00, 177.40it/s]
# --- EPOCH 7/100 ---
# train_batch (Avg. Loss 1.339, Accuracy 52.4): 100% 100/100 [00:02<00:00, 42.27it/s]
# test_batch (Avg. Loss 1.317, Accuracy 51.8): 100% 100/100 [00:00<00:00, 180.88it/s]
# --- EPOCH 8/100 ---
# train_batch (Avg. Loss 1.293, Accuracy 53.9): 100% 100/100 [00:02<00:00, 42.34it/s]
# test_batch (Avg. Loss 1.301, Accuracy 52.9): 100% 100/100 [00:00<00:00, 180.59it/s]
# --- EPOCH 9/100 ---
# train_batch (Avg. Loss 1.242, Accuracy 55.9): 100% 100/100 [00:02<00:00, 41.93it/s]
# test_batch (Avg. Loss 1.232, Accuracy 55.9): 100% 100/100 [00:00<00:00, 181.27it/s]
# --- EPOCH 10/100 ---
# train_batch (Avg. Loss 1.220, Accuracy 56.7): 100% 100/100 [00:02<00:00, 42.36it/s]
# test_batch (Avg. Loss 1.201, Accuracy 57.5): 100% 100/100 [00:00<00:00, 177.75it/s]
# --- EPOCH 11/100 ---
# train_batch (Avg. Loss 1.176, Accuracy 58.1): 100% 100/100 [00:02<00:00, 41.50it/s]
# test_batch (Avg. Loss 1.204, Accuracy 56.9): 100% 100/100 [00:00<00:00, 178.49it/s]
# --- EPOCH 12/100 ---
# train_batch (Avg. Loss 1.156, Accuracy 59.3): 100% 100/100 [00:02<00:00, 42.16it/s]
# test_batch (Avg. Loss 1.187, Accuracy 57.8): 100% 100/100 [00:00<00:00, 177.33it/s]
# --- EPOCH 13/100 ---
# train_batch (Avg. Loss 1.096, Accuracy 61.2): 100% 100/100 [00:02<00:00, 42.42it/s]
# test_batch (Avg. Loss 1.157, Accuracy 58.5): 100% 100/100 [00:00<00:00, 181.85it/s]
# --- EPOCH 14/100 ---
# train_batch (Avg. Loss 1.079, Accuracy 61.7): 100% 100/100 [00:02<00:00, 42.37it/s]
# test_batch (Avg. Loss 1.108, Accuracy 60.5): 100% 100/100 [00:00<00:00, 179.73it/s]
# --- EPOCH 15/100 ---
# train_batch (Avg. Loss 1.043, Accuracy 63.3): 100% 100/100 [00:02<00:00, 41.59it/s]
# test_batch (Avg. Loss 1.107, Accuracy 60.4): 100% 100/100 [00:00<00:00, 173.20it/s]
# --- EPOCH 16/100 ---
# train_batch (Avg. Loss 1.024, Accuracy 64.0): 100% 100/100 [00:02<00:00, 42.06it/s]
# test_batch (Avg. Loss 1.070, Accuracy 62.5): 100% 100/100 [00:00<00:00, 177.24it/s]
# --- EPOCH 17/100 ---
# train_batch (Avg. Loss 1.014, Accuracy 64.3): 100% 100/100 [00:02<00:00, 42.35it/s]
# test_batch (Avg. Loss 1.077, Accuracy 61.7): 100% 100/100 [00:00<00:00, 182.39it/s]
# --- EPOCH 18/100 ---
# train_batch (Avg. Loss 0.975, Accuracy 66.2): 100% 100/100 [00:02<00:00, 42.53it/s]
# test_batch (Avg. Loss 1.021, Accuracy 63.6): 100% 100/100 [00:00<00:00, 177.54it/s]
# --- EPOCH 19/100 ---
# train_batch (Avg. Loss 0.977, Accuracy 65.7): 100% 100/100 [00:02<00:00, 41.51it/s]
# test_batch (Avg. Loss 0.994, Accuracy 65.8): 100% 100/100 [00:00<00:00, 179.58it/s]
# --- EPOCH 20/100 ---
# train_batch (Avg. Loss 0.933, Accuracy 67.2): 100% 100/100 [00:02<00:00, 41.98it/s]
# test_batch (Avg. Loss 1.000, Accuracy 64.9): 100% 100/100 [00:00<00:00, 177.97it/s]
# --- EPOCH 21/100 ---
# train_batch (Avg. Loss 0.924, Accuracy 67.6): 100% 100/100 [00:02<00:00, 42.54it/s]
# test_batch (Avg. Loss 0.982, Accuracy 65.5): 100% 100/100 [00:00<00:00, 179.60it/s]
# --- EPOCH 22/100 ---
# train_batch (Avg. Loss 0.902, Accuracy 68.5): 100% 100/100 [00:02<00:00, 42.23it/s]
# test_batch (Avg. Loss 1.003, Accuracy 64.5): 100% 100/100 [00:00<00:00, 178.59it/s]
# *** Output file ./results/exp1_3_L3_K64-128_L3_K64-128.json written
# Running: python -m hw2.experiments run-exp --run-name exp1_3_L4_K64-128 --lr 0.0001 --filters-per-layer 64 128 --layers-per-block 4 --pool-every 4 --hidden-dims 1024 --model-type cnn
# *** Starting cnn_experiment with config:
# Namespace(run_name='exp1_3_L4_K64-128', out_dir='./results', seed=None, device=None, bs_train=128, bs_test=None, batches=100, epochs=100, early_stopping=3, checkpoints=None, lr=0.0001, reg=0.001, filters_per_layer=[64, 128], layers_per_block=4, pool_every=4, hidden_dims=[1024], model_type='cnn')
# Files already downloaded and verified
# Files already downloaded and verified
# --- EPOCH 1/100 ---
# train_batch (Avg. Loss 2.176, Accuracy 18.3): 100% 100/100 [00:02<00:00, 34.21it/s]
# test_batch (Avg. Loss 1.992, Accuracy 28.7): 100% 100/100 [00:00<00:00, 170.71it/s]
# --- EPOCH 2/100 ---
# train_batch (Avg. Loss 1.931, Accuracy 30.1): 100% 100/100 [00:02<00:00, 38.83it/s]
# test_batch (Avg. Loss 1.791, Accuracy 38.6): 100% 100/100 [00:00<00:00, 172.76it/s]
# --- EPOCH 3/100 ---
# train_batch (Avg. Loss 1.695, Accuracy 39.1): 100% 100/100 [00:02<00:00, 39.05it/s]
# test_batch (Avg. Loss 1.613, Accuracy 42.6): 100% 100/100 [00:00<00:00, 173.33it/s]
# --- EPOCH 4/100 ---
# train_batch (Avg. Loss 1.563, Accuracy 43.4): 100% 100/100 [00:02<00:00, 39.22it/s]
# test_batch (Avg. Loss 1.488, Accuracy 45.8): 100% 100/100 [00:00<00:00, 175.16it/s]
# --- EPOCH 5/100 ---
# train_batch (Avg. Loss 1.480, Accuracy 46.6): 100% 100/100 [00:02<00:00, 39.27it/s]
# test_batch (Avg. Loss 1.427, Accuracy 48.4): 100% 100/100 [00:00<00:00, 173.74it/s]
# --- EPOCH 6/100 ---
# train_batch (Avg. Loss 1.425, Accuracy 48.8): 100% 100/100 [00:02<00:00, 39.48it/s]
# test_batch (Avg. Loss 1.386, Accuracy 50.6): 100% 100/100 [00:00<00:00, 172.33it/s]
# --- EPOCH 7/100 ---
# train_batch (Avg. Loss 1.376, Accuracy 50.7): 100% 100/100 [00:02<00:00, 38.75it/s]
# test_batch (Avg. Loss 1.347, Accuracy 51.6): 100% 100/100 [00:00<00:00, 174.11it/s]
# --- EPOCH 8/100 ---
# train_batch (Avg. Loss 1.323, Accuracy 53.2): 100% 100/100 [00:02<00:00, 38.99it/s]
# test_batch (Avg. Loss 1.321, Accuracy 52.2): 100% 100/100 [00:00<00:00, 172.54it/s]
# --- EPOCH 9/100 ---
# train_batch (Avg. Loss 1.298, Accuracy 53.5): 100% 100/100 [00:02<00:00, 39.26it/s]
# test_batch (Avg. Loss 1.313, Accuracy 52.8): 100% 100/100 [00:00<00:00, 174.26it/s]
# --- EPOCH 10/100 ---
# train_batch (Avg. Loss 1.284, Accuracy 54.1): 100% 100/100 [00:02<00:00, 38.96it/s]
# test_batch (Avg. Loss 1.268, Accuracy 54.0): 100% 100/100 [00:00<00:00, 170.22it/s]
# --- EPOCH 11/100 ---
# train_batch (Avg. Loss 1.240, Accuracy 55.7): 100% 100/100 [00:02<00:00, 38.69it/s]
# test_batch (Avg. Loss 1.244, Accuracy 55.1): 100% 100/100 [00:00<00:00, 173.33it/s]
# --- EPOCH 12/100 ---
# train_batch (Avg. Loss 1.198, Accuracy 57.1): 100% 100/100 [00:02<00:00, 39.12it/s]
# test_batch (Avg. Loss 1.245, Accuracy 55.7): 100% 100/100 [00:00<00:00, 172.96it/s]
# --- EPOCH 13/100 ---
# train_batch (Avg. Loss 1.170, Accuracy 58.4): 100% 100/100 [00:02<00:00, 39.28it/s]
# test_batch (Avg. Loss 1.192, Accuracy 56.2): 100% 100/100 [00:00<00:00, 168.48it/s]
# --- EPOCH 14/100 ---
# train_batch (Avg. Loss 1.151, Accuracy 59.3): 100% 100/100 [00:02<00:00, 39.14it/s]
# test_batch (Avg. Loss 1.172, Accuracy 57.4): 100% 100/100 [00:00<00:00, 171.58it/s]
# --- EPOCH 15/100 ---
# train_batch (Avg. Loss 1.150, Accuracy 59.6): 100% 100/100 [00:02<00:00, 38.23it/s]
# test_batch (Avg. Loss 1.158, Accuracy 58.6): 100% 100/100 [00:00<00:00, 174.63it/s]
# --- EPOCH 16/100 ---
# train_batch (Avg. Loss 1.116, Accuracy 60.8): 100% 100/100 [00:02<00:00, 39.28it/s]
# test_batch (Avg. Loss 1.141, Accuracy 59.1): 100% 100/100 [00:00<00:00, 173.65it/s]
# --- EPOCH 17/100 ---
# train_batch (Avg. Loss 1.081, Accuracy 61.7): 100% 100/100 [00:02<00:00, 39.26it/s]
# test_batch (Avg. Loss 1.158, Accuracy 58.3): 100% 100/100 [00:00<00:00, 174.07it/s]
# --- EPOCH 18/100 ---
# train_batch (Avg. Loss 1.060, Accuracy 62.7): 100% 100/100 [00:02<00:00, 38.79it/s]
# test_batch (Avg. Loss 1.092, Accuracy 60.9): 100% 100/100 [00:00<00:00, 169.35it/s]
# --- EPOCH 19/100 ---
# train_batch (Avg. Loss 1.034, Accuracy 63.1): 100% 100/100 [00:02<00:00, 38.82it/s]
# test_batch (Avg. Loss 1.095, Accuracy 60.6): 100% 100/100 [00:00<00:00, 173.35it/s]
# --- EPOCH 20/100 ---
# train_batch (Avg. Loss 1.029, Accuracy 64.0): 100% 100/100 [00:02<00:00, 39.23it/s]
# test_batch (Avg. Loss 1.088, Accuracy 60.3): 100% 100/100 [00:00<00:00, 176.66it/s]
# --- EPOCH 21/100 ---
# train_batch (Avg. Loss 0.995, Accuracy 64.8): 100% 100/100 [00:02<00:00, 39.31it/s]
# test_batch (Avg. Loss 1.047, Accuracy 62.8): 100% 100/100 [00:00<00:00, 175.41it/s]
# --- EPOCH 22/100 ---
# train_batch (Avg. Loss 0.954, Accuracy 66.5): 100% 100/100 [00:02<00:00, 39.22it/s]
# test_batch (Avg. Loss 1.024, Accuracy 64.0): 100% 100/100 [00:00<00:00, 174.82it/s]
# --- EPOCH 23/100 ---
# train_batch (Avg. Loss 0.938, Accuracy 67.2): 100% 100/100 [00:02<00:00, 38.99it/s]
# test_batch (Avg. Loss 1.048, Accuracy 62.9): 100% 100/100 [00:00<00:00, 174.08it/s]
# --- EPOCH 24/100 ---
# train_batch (Avg. Loss 0.909, Accuracy 68.2): 100% 100/100 [00:02<00:00, 39.49it/s]
# test_batch (Avg. Loss 1.035, Accuracy 63.5): 100% 100/100 [00:00<00:00, 174.30it/s]
# --- EPOCH 25/100 ---
# train_batch (Avg. Loss 0.912, Accuracy 68.3): 100% 100/100 [00:02<00:00, 39.36it/s]
# test_batch (Avg. Loss 1.041, Accuracy 64.3): 100% 100/100 [00:00<00:00, 169.78it/s]
# --- EPOCH 26/100 ---
# train_batch (Avg. Loss 0.904, Accuracy 68.1): 100% 100/100 [00:02<00:00, 39.26it/s]
# test_batch (Avg. Loss 1.018, Accuracy 64.1): 100% 100/100 [00:00<00:00, 174.12it/s]
# --- EPOCH 27/100 ---
# train_batch (Avg. Loss 0.900, Accuracy 68.5): 100% 100/100 [00:02<00:00, 38.72it/s]
# test_batch (Avg. Loss 1.003, Accuracy 65.4): 100% 100/100 [00:00<00:00, 175.01it/s]
# --- EPOCH 28/100 ---
# train_batch (Avg. Loss 0.873, Accuracy 69.8): 100% 100/100 [00:02<00:00, 39.18it/s]
# test_batch (Avg. Loss 1.009, Accuracy 64.3): 100% 100/100 [00:00<00:00, 175.38it/s]
# --- EPOCH 29/100 ---
# train_batch (Avg. Loss 0.854, Accuracy 70.0): 100% 100/100 [00:02<00:00, 39.16it/s]
# test_batch (Avg. Loss 0.992, Accuracy 66.2): 100% 100/100 [00:00<00:00, 174.03it/s]
# --- EPOCH 30/100 ---
# train_batch (Avg. Loss 0.833, Accuracy 70.7): 100% 100/100 [00:02<00:00, 39.07it/s]
# test_batch (Avg. Loss 1.007, Accuracy 65.3): 100% 100/100 [00:00<00:00, 173.90it/s]
# --- EPOCH 31/100 ---
# train_batch (Avg. Loss 0.819, Accuracy 71.3): 100% 100/100 [00:02<00:00, 38.87it/s]
# test_batch (Avg. Loss 0.986, Accuracy 65.6): 100% 100/100 [00:00<00:00, 173.73it/s]
# --- EPOCH 32/100 ---
# train_batch (Avg. Loss 0.803, Accuracy 71.9): 100% 100/100 [00:02<00:00, 39.17it/s]
# test_batch (Avg. Loss 0.955, Accuracy 66.9): 100% 100/100 [00:00<00:00, 174.94it/s]
# --- EPOCH 33/100 ---
# train_batch (Avg. Loss 0.788, Accuracy 72.4): 100% 100/100 [00:02<00:00, 39.14it/s]
# test_batch (Avg. Loss 0.977, Accuracy 66.0): 100% 100/100 [00:00<00:00, 173.74it/s]
# --- EPOCH 34/100 ---
# train_batch (Avg. Loss 0.773, Accuracy 73.2): 100% 100/100 [00:02<00:00, 39.19it/s]
# test_batch (Avg. Loss 0.978, Accuracy 66.7): 100% 100/100 [00:00<00:00, 168.36it/s]
# --- EPOCH 35/100 ---
# train_batch (Avg. Loss 0.773, Accuracy 73.2): 100% 100/100 [00:02<00:00, 37.92it/s]
# test_batch (Avg. Loss 0.954, Accuracy 67.9): 100% 100/100 [00:00<00:00, 174.01it/s]
# --- EPOCH 36/100 ---
# train_batch (Avg. Loss 0.751, Accuracy 73.7): 100% 100/100 [00:02<00:00, 39.45it/s]
# test_batch (Avg. Loss 0.978, Accuracy 67.6): 100% 100/100 [00:00<00:00, 172.91it/s]
# --- EPOCH 37/100 ---
# train_batch (Avg. Loss 0.747, Accuracy 74.3): 100% 100/100 [00:02<00:00, 39.36it/s]
# test_batch (Avg. Loss 0.964, Accuracy 67.5): 100% 100/100 [00:00<00:00, 174.67it/s]
# --- EPOCH 38/100 ---
# train_batch (Avg. Loss 0.721, Accuracy 75.0): 100% 100/100 [00:02<00:00, 39.20it/s]
# test_batch (Avg. Loss 0.952, Accuracy 67.5): 100% 100/100 [00:00<00:00, 170.82it/s]
# *** Output file ./results/exp1_3_L4_K64-128_L4_K64-128.json written

# %%
plot_exp_results('exp1_3*.json')
# Out:
# common config:  {'run_name': 'exp1_3_L4_K64-128', 'out_dir': './results', 'seed': 689441865, 'device': None, 'bs_train': 128, 'bs_test': 32, 'batches': 100, 'epochs': 100, 'early_stopping': 3, 'checkpoints': None, 'lr': 0.0001, 'reg': 0.001, 'pool_every': 4, 'hidden_dims': [1024], 'model_type': 'cnn', 'activation_type': 'lrelu', 'activation_params': {'negative_slope': 0.5}, 'conv_params': {'kernel_size': 3, 'stride': 1, 'padding': 1}, 'pooling_type': 'max', 'pooling_params': {'kernel_size': 2, 'stride': 2}, 'batchnorm': True, 'dropout': 0.2, 'kw': {}}

# %% [markdown]
# #### Experiment 1.4: Adding depth with Residual Networks

# %% [markdown]
# Now we'll test the effect of skip connections on the training and performance.
#
# **Configuratons**:
# - `K=[32]` fixed with `L=8,16,32` varying per run.
# - `K=[64, 128, 256]` fixed with `L=2,4,8` varying per run.
#
# So 6 different runs in total.
#
# **Naming runs**:
# Each run should be named `exp1_4_L{}_K{}-{}-{}` where the braces are placeholders for the values.

# %% [markdown]
# **TODO**: Run the experiment on the above configuration with the `ResNet` model. Make sure the result file names are as expected. Use the following blocks to display the results.

# %%
from hw2.experiments import cnn_experiment

configs = [
    {"filters_per_layer": [32], "layers_per_block_list": [8, 16, 32]},  # First set of runs
    {"filters_per_layer": [64, 128, 256], "layers_per_block_list": [2, 4, 8]},  # Second set of runs
]


hidden_dims = 1024

for config in configs:
    K = config["filters_per_layer"]
    for L in config["layers_per_block_list"]:
        run_name = f"exp1_4_L{L}_K{'-'.join(map(str, K))}"
        command = (
            f"python -m hw2.experiments run-exp "
            f"--run-name {run_name} "
            f"--filters-per-layer {' '.join(map(str, K))} "
            f"--layers-per-block {L} "
            f"--pool-every {L} "
            f"--hidden-dims {hidden_dims} "
            # f"--epochs {epochs} "
            f"--model-type resnet "
        )
        print(f"Running: {command}")
        # os.system(command)
        # !{command}
# Out:
# Running: python -m hw2.experiments run-exp --run-name exp1_4_L8_K32 --filters-per-layer 32 --layers-per-block 8 --pool-every 8 --hidden-dims 1024 --model-type resnet
# *** Starting cnn_experiment with config:
# Namespace(run_name='exp1_4_L8_K32', out_dir='./results', seed=None, device=None, bs_train=128, bs_test=None, batches=100, epochs=100, early_stopping=3, checkpoints=None, lr=0.001, reg=0.001, filters_per_layer=[32], layers_per_block=8, pool_every=8, hidden_dims=[1024], model_type='resnet')
# Files already downloaded and verified
# Files already downloaded and verified
# --- EPOCH 1/100 ---
# train_batch (Avg. Loss 2.542, Accuracy 15.8): 100% 100/100 [00:03<00:00, 26.64it/s]
# test_batch (Avg. Loss 2.214, Accuracy 19.7): 100% 100/100 [00:00<00:00, 152.69it/s]
# --- EPOCH 2/100 ---
# train_batch (Avg. Loss 2.088, Accuracy 25.0): 100% 100/100 [00:03<00:00, 32.14it/s]
# test_batch (Avg. Loss 1.938, Accuracy 28.4): 100% 100/100 [00:00<00:00, 157.04it/s]
# --- EPOCH 3/100 ---
# train_batch (Avg. Loss 1.897, Accuracy 30.5): 100% 100/100 [00:03<00:00, 32.45it/s]
# test_batch (Avg. Loss 1.834, Accuracy 31.6): 100% 100/100 [00:00<00:00, 160.04it/s]
# --- EPOCH 4/100 ---
# train_batch (Avg. Loss 1.818, Accuracy 34.0): 100% 100/100 [00:03<00:00, 32.65it/s]
# test_batch (Avg. Loss 1.721, Accuracy 37.1): 100% 100/100 [00:00<00:00, 158.37it/s]
# --- EPOCH 5/100 ---
# train_batch (Avg. Loss 1.741, Accuracy 36.3): 100% 100/100 [00:03<00:00, 32.21it/s]
# test_batch (Avg. Loss 1.786, Accuracy 36.1): 100% 100/100 [00:00<00:00, 155.85it/s]
# --- EPOCH 6/100 ---
# train_batch (Avg. Loss 1.652, Accuracy 39.8): 100% 100/100 [00:03<00:00, 32.37it/s]
# test_batch (Avg. Loss 1.546, Accuracy 41.4): 100% 100/100 [00:00<00:00, 158.25it/s]
# --- EPOCH 7/100 ---
# train_batch (Avg. Loss 1.555, Accuracy 43.0): 100% 100/100 [00:03<00:00, 32.68it/s]
# test_batch (Avg. Loss 1.445, Accuracy 47.5): 100% 100/100 [00:00<00:00, 157.80it/s]
# --- EPOCH 8/100 ---
# train_batch (Avg. Loss 1.494, Accuracy 45.4): 100% 100/100 [00:03<00:00, 32.22it/s]
# test_batch (Avg. Loss 1.414, Accuracy 47.2): 100% 100/100 [00:00<00:00, 158.62it/s]
# --- EPOCH 9/100 ---
# train_batch (Avg. Loss 1.485, Accuracy 46.4): 100% 100/100 [00:03<00:00, 32.10it/s]
# test_batch (Avg. Loss 1.352, Accuracy 50.8): 100% 100/100 [00:00<00:00, 157.77it/s]
# --- EPOCH 10/100 ---
# train_batch (Avg. Loss 1.428, Accuracy 48.1): 100% 100/100 [00:03<00:00, 32.49it/s]
# test_batch (Avg. Loss 1.362, Accuracy 50.1): 100% 100/100 [00:00<00:00, 160.93it/s]
# --- EPOCH 11/100 ---
# train_batch (Avg. Loss 1.389, Accuracy 50.0): 100% 100/100 [00:03<00:00, 32.62it/s]
# test_batch (Avg. Loss 1.361, Accuracy 51.0): 100% 100/100 [00:00<00:00, 162.10it/s]
# --- EPOCH 12/100 ---
# train_batch (Avg. Loss 1.360, Accuracy 51.4): 100% 100/100 [00:03<00:00, 31.89it/s]
# test_batch (Avg. Loss 1.333, Accuracy 52.2): 100% 100/100 [00:00<00:00, 158.48it/s]
# --- EPOCH 13/100 ---
# train_batch (Avg. Loss 1.338, Accuracy 51.8): 100% 100/100 [00:03<00:00, 32.49it/s]
# test_batch (Avg. Loss 1.256, Accuracy 54.4): 100% 100/100 [00:00<00:00, 156.99it/s]
# --- EPOCH 14/100 ---
# train_batch (Avg. Loss 1.302, Accuracy 53.3): 100% 100/100 [00:03<00:00, 32.51it/s]
# test_batch (Avg. Loss 1.248, Accuracy 56.2): 100% 100/100 [00:00<00:00, 155.20it/s]
# --- EPOCH 15/100 ---
# train_batch (Avg. Loss 1.249, Accuracy 55.5): 100% 100/100 [00:03<00:00, 32.04it/s]
# test_batch (Avg. Loss 1.259, Accuracy 54.6): 100% 100/100 [00:00<00:00, 158.98it/s]
# --- EPOCH 16/100 ---
# train_batch (Avg. Loss 1.241, Accuracy 55.6): 100% 100/100 [00:03<00:00, 32.33it/s]
# test_batch (Avg. Loss 1.227, Accuracy 56.3): 100% 100/100 [00:00<00:00, 160.68it/s]
# --- EPOCH 17/100 ---
# train_batch (Avg. Loss 1.201, Accuracy 57.4): 100% 100/100 [00:03<00:00, 32.58it/s]
# test_batch (Avg. Loss 1.147, Accuracy 58.6): 100% 100/100 [00:00<00:00, 159.10it/s]
# --- EPOCH 18/100 ---
# train_batch (Avg. Loss 1.200, Accuracy 57.5): 100% 100/100 [00:03<00:00, 32.34it/s]
# test_batch (Avg. Loss 1.158, Accuracy 58.7): 100% 100/100 [00:00<00:00, 156.10it/s]
# --- EPOCH 19/100 ---
# train_batch (Avg. Loss 1.186, Accuracy 58.3): 100% 100/100 [00:03<00:00, 32.37it/s]
# test_batch (Avg. Loss 1.177, Accuracy 58.9): 100% 100/100 [00:00<00:00, 161.36it/s]
# --- EPOCH 20/100 ---
# train_batch (1.107):  78% 78/100 [00:02<00:00, 32.18it/s]
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/drive/MyDrive/HW2/deephw2/hw2/experiments.py", line 318, in <module>
#     subcmd_fn(**vars(parsed_args))
#   File "/content/drive/MyDrive/HW2/deephw2/hw2/experiments.py", line 153, in cnn_experiment
#     fit_res = trainer.fit(
#   File "/content/drive/MyDrive/HW2/deephw2/hw2/training.py", line 86, in fit
# ^C
# Running: python -m hw2.experiments run-exp --run-name exp1_4_L16_K32 --filters-per-layer 32 --layers-per-block 16 --pool-every 16 --hidden-dims 1024 --model-type resnet
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/drive/MyDrive/HW2/deephw2/hw2/experiments.py", line 5, in <module>
#     import torch
#   File "/usr/local/lib/python3.10/dist-packages/torch/__init__.py", line 2016, in <module>
#     from torch import _VF as _VF, functional as functional  # usort: skip
#   File "/usr/local/lib/python3.10/dist-packages/torch/functional.py", line 7, in <module>
#     import torch.nn.functional as F
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/__init__.py", line 8, in <module>
#     from torch.nn.modules import *  # usort: skip # noqa: F403
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/__init__.py", line 1, in <module>
#     from .module import Module  # usort: skip
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 27, in <module>
#     from torch._prims_common import DeviceLikeType
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 879, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1012, in get_code
#   File "<frozen importlib._bootstrap_external>", line 672, in _compile_bytecode
# KeyboardInterrupt
# ^C
# Running: python -m hw2.experiments run-exp --run-name exp1_4_L32_K32 --filters-per-layer 32 --layers-per-block 32 --pool-every 32 --hidden-dims 1024 --model-type resnet
# Traceback (most recent call last):
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/__init__.py", line 39, in <module>
#     from .polyfills import loader as _  # usort: skip # noqa: F401
#   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/polyfills/loader.py", line 22, in <module>
#     POLYFILLED_MODULES: Tuple["ModuleType", ...] = tuple(
#   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/polyfills/loader.py", line 23, in <genexpr>
#     importlib.import_module(f".{submodule}", package=polyfills.__name__)
#   File "/usr/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/polyfills/builtins.py", line 24, in <module>
#     def all(iterable: Iterable[object], /) -> bool:
#   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/decorators.py", line 312, in wrapper
#     rule_map: Dict[Any, Type[VariableTracker]] = get_torch_obj_rule_map()
#   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/trace_rules.py", line 2860, in get_torch_obj_rule_map
#     obj = load_object(k)
#   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/trace_rules.py", line 2891, in load_object
#     val = _load_obj_from_str(x[0])
#   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/trace_rules.py", line 2875, in _load_obj_from_str
#     return getattr(importlib.import_module(module), obj_name)
#   File "/usr/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/usr/local/lib/python3.10/dist-packages/torch/_higher_order_ops/map.py", line 6, in <module>
#     from torch._functorch.aot_autograd import AOTConfig, create_joint
#   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/aot_autograd.py", line 32, in <module>
#     from ._aot_autograd.autograd_cache import (  # noqa: F401
#   File "/usr/local/lib/python3.10/dist-packages/torch/_functorch/_aot_autograd/autograd_cache.py", line 19, in <module>
#     from torch._inductor.codecache import (
#   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/codecache.py", line 57, in <module>
#     from torch._inductor import config, exc, metrics
#   File "/usr/local/lib/python3.10/dist-packages/torch/_inductor/exc.py", line 56, in <module>
#     class LoweringException(OperatorIssue):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/drive/MyDrive/HW2/deephw2/hw2/experiments.py", line 9, in <module>
#     import torchvision
#   File "/usr/local/lib/python3.10/dist-packages/torchvision/__init__.py", line 10, in <module>
#     from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils  # usort:skip
#   File "/usr/local/lib/python3.10/dist-packages/torchvision/models/__init__.py", line 2, in <module>
#     from .convnext import *
#   File "/usr/local/lib/python3.10/dist-packages/torchvision/models/convnext.py", line 8, in <module>
#     from ..ops.misc import Conv2dNormActivation, Permute
#   File "/usr/local/lib/python3.10/dist-packages/torchvision/ops/__init__.py", line 23, in <module>
#     from .poolers import MultiScaleRoIAlign
#   File "/usr/local/lib/python3.10/dist-packages/torchvision/ops/poolers.py", line 10, in <module>
#     from .roi_align import roi_align
#   File "/usr/local/lib/python3.10/dist-packages/torchvision/ops/roi_align.py", line 7, in <module>
#     from torch._dynamo.utils import is_compile_supported
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
# KeyboardInterrupt
# Running: python -m hw2.experiments run-exp --run-name exp1_4_L2_K64-128-256 --filters-per-layer 64 128 256 --layers-per-block 2 --pool-every 2 --hidden-dims 1024 --model-type resnet
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/drive/MyDrive/HW2/deephw2/hw2/experiments.py", line 5, in <module>
#     import torch
#   File "/usr/local/lib/python3.10/dist-packages/torch/__init__.py", line 367, in <module>
#     from torch._C import *  # noqa: F403
#   File "<frozen importlib._bootstrap>", line 216, in _lock_unlock_module
# KeyboardInterrupt
# ^C
# Running: python -m hw2.experiments run-exp --run-name exp1_4_L4_K64-128-256 --filters-per-layer 64 128 256 --layers-per-block 4 --pool-every 4 --hidden-dims 1024 --model-type resnet
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/drive/MyDrive/HW2/deephw2/hw2/experiments.py", line 5, in <module>
#     import torch
#   File "/usr/local/lib/python3.10/dist-packages/torch/__init__.py", line 367, in <module>
#     from torch._C import *  # noqa: F403
#   File "<frozen importlib._bootstrap>", line 216, in _lock_unlock_module
# KeyboardInterrupt
# ^C
# Running: python -m hw2.experiments run-exp --run-name exp1_4_L8_K64-128-256 --filters-per-layer 64 128 256 --layers-per-block 8 --pool-every 8 --hidden-dims 1024 --model-type resnet
# Traceback (most recent call last):
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.10/dist-packages/torch/fx/experimental/symbolic_shapes.py", line 65, in <module>
#     from torch.utils._sympy.functions import (
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_sympy/functions.py", line 7, in <module>
#     import sympy
#   File "/usr/local/lib/python3.10/dist-packages/sympy/__init__.py", line 74, in <module>
#     from .polys import (Poly, PurePoly, poly_from_expr, parallel_poly_from_expr,
#   File "/usr/local/lib/python3.10/dist-packages/sympy/polys/__init__.py", line 94, in <module>
#     from .numberfields import (minpoly, minimal_polynomial, primitive_element,
#   File "/usr/local/lib/python3.10/dist-packages/sympy/polys/numberfields/__init__.py", line 21, in <module>
#     from .utilities import isolate
#   File "/usr/local/lib/python3.10/dist-packages/sympy/polys/numberfields/utilities.py", line 7, in <module>
#     from sympy.polys.matrices.exceptions import DMRankError
#   File "/usr/local/lib/python3.10/dist-packages/sympy/polys/matrices/__init__.py", line 11, in <module>
#     from .domainmatrix import DomainMatrix, DM
#   File "/usr/local/lib/python3.10/dist-packages/sympy/polys/matrices/domainmatrix.py", line 25, in <module>
#     from .exceptions import (
#   File "/usr/local/lib/python3.10/dist-packages/sympy/polys/matrices/exceptions.py", line 38, in <module>
#     class DMNonInvertibleMatrixError(DMError):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/drive/MyDrive/HW2/deephw2/hw2/experiments.py", line 9, in <module>
#     import torchvision
#   File "/usr/local/lib/python3.10/dist-packages/torchvision/__init__.py", line 10, in <module>
#     from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils  # usort:skip
#   File "/usr/local/lib/python3.10/dist-packages/torchvision/models/__init__.py", line 2, in <module>
#     from .convnext import *
#   File "/usr/local/lib/python3.10/dist-packages/torchvision/models/convnext.py", line 8, in <module>
#     from ..ops.misc import Conv2dNormActivation, Permute
#   File "/usr/local/lib/python3.10/dist-packages/torchvision/ops/__init__.py", line 23, in <module>
#     from .poolers import MultiScaleRoIAlign
#   File "/usr/local/lib/python3.10/dist-packages/torchvision/ops/poolers.py", line 10, in <module>
#     from .roi_align import roi_align
#   File "/usr/local/lib/python3.10/dist-packages/torchvision/ops/roi_align.py", line 7, in <module>
#     from torch._dynamo.utils import is_compile_supported
#   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/__init__.py", line 3, in <module>
#     from . import convert_frame, eval_frame, resume_execution
#   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/convert_frame.py", line 31, in <module>
#     from torch._dynamo.utils import CompileTimeInstructionCounter
#   File "/usr/local/lib/python3.10/dist-packages/torch/_dynamo/utils.py", line 62, in <module>
#     import torch.fx.experimental.symbolic_shapes
#   File "<frozen importlib._bootstrap>", line 1024, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 174, in __exit__
#   File "<frozen importlib._bootstrap>", line 128, in release
# KeyboardInterrupt
# ^C

# %%
plot_exp_results('exp1_4_L*_K32.json')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-0a1b3bc69489> in <cell line: 1>()
# ----> 1 plot_exp_results('exp1_4_L*_K32.json')
#
# <ipython-input-7-86324a873fe1> in plot_exp_results(filename_pattern, results_dir)
#       8     for filepath in result_files:
#       9         m = re.match('exp\d_(\d_)?(.*)\.json', os.path.basename(filepath))
# ---> 10         cfg, fit_res = load_experiment(filepath)
#      11         fig, axes = plot_fit(fit_res, fig, legend=m[2],log_loss=True)
#      12     del cfg['filters_per_layer']
#
# /content/drive/MyDrive/HW2/deephw2/hw2/experiments.py in load_experiment(filename)
#     181 def load_experiment(filename):
#     182     with open(filename, "r") as f:
# --> 183         output = json.load(f)
#     184
#     185     config = output["config"]
#
# /usr/lib/python3.10/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# /usr/lib/python3.10/codecs.py in decode(self, input, final)
#     317         raise NotImplementedError
#     318
# --> 319     def decode(self, input, final=False):
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
#
# KeyboardInterrupt:

# %%
plot_exp_results('exp1_4_L*_K64*.json')
# Out:
# common config:  {'run_name': 'exp1_4_L8_K64-128-256', 'out_dir': './results', 'seed': 525417056, 'device': None, 'bs_train': 128, 'bs_test': 32, 'batches': 100, 'epochs': 100, 'early_stopping': 3, 'checkpoints': None, 'lr': 0.001, 'reg': 0.001, 'pool_every': 8, 'hidden_dims': [1024], 'model_type': 'resnet', 'activation_type': 'relu', 'activation_params': {}, 'conv_params': {'kernel_size': 3, 'stride': 1, 'padding': 1}, 'pooling_type': 'avg', 'pooling_params': {'kernel_size': 2, 'stride': 2}, 'batchnorm': True, 'dropout': 0.2, 'kw': {}}

# %% [markdown]
# ## Questions
# <a id=part5_4></a>

# %% [markdown]
# **TODO** Answer the following questions. Write your answers in the appropriate variables in the module `hw2/answers.py`.

# %%
from cs236781.answers import display_answer
import hw2.answers

# %% [markdown]
# ### Question 1
#
# Analyze your results from experiment 1.1. In particular,
# 1.  Explain the effect of depth on the accuracy. What depth produces the best results and why do you think that's the case?
# 1. Were there values of `L` for which the network wasn't trainable? what causes this? Suggest two things which may be done to resolve it at least partially.

# %%
display_answer(hw2.answers.part5_q1)

# %% [markdown]
# ### Question 2
#
# Analyze your results from experiment 1.2. In particular, compare to the results of experiment 1.1.

# %%
display_answer(hw2.answers.part5_q2)

# %% [markdown]
# ### Question 3
#
# Analyze your results from experiment 1.3.

# %%
display_answer(hw2.answers.part5_q3)

# %% [markdown]
# ### Question 4
#
# Analyze your results from experiment 1.4. Compare to experiment 1.1 and 1.3.

# %%
display_answer(hw2.answers.part5_q4)

# %%
display_answer(hw2.answers.part5_q5)
